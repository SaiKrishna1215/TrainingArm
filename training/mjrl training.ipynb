# %% [markdown]
# <h1> MJRL training </h1>
# MJRL Algorithms: TRPO - MBAC - PPO - NPG - DAPG <br>
# source: https://github.com/aravindr93/mjrl/tree/master/mjrl/algos

# %%
import warnings
warnings.filterwarnings('ignore')

import gym
from mjrl.utils.gym_env import GymEnv
from mjrl.policies.gaussian_mlp import MLP
from mjrl.baselines.mlp_baseline import MLPBaseline
from mjrl.algos.ppo_clip import PPO
from mjrl.algos.npg_cg import NPG
from mjrl.utils.train_agent import train_agent
import myosuite

# Create the environment
# Find tasks in: \envs\myo\myobase or \envs\myo\myochallenge
env = gym.make('CenterReachOut-v0')

env.reset()
# Out:
# MyoSuite:> Registering Myo Envs
#     MyoSuite: A contact-rich simulation suite for musculoskeletal motor control
#         Vittorio Caggiano, Huawei Wang, Guillaume Durandau, Massimo Sartori, Vikash Kumar
#         L4DC-2019 | https://sites.google.com/view/myosuite
# array([-2.2856e-02,  1.1130e-02, -8.2680e-02,  1.0125e-01, -4.9400e-02,
#         1.6578e-01,  1.1868e-01, -1.9320e-01, -1.9648e-01,  3.8760e-02,
#         1.6806e-01,  1.7281e-01, -2.5407e-01, -1.0998e-01,  1.4748e+00,
#         1.2882e+00,  1.0647e-01, -2.7489e-01,  3.3200e-01,  4.1140e-01,
#        -1.7716e-01, -2.6182e-01,  1.8852e-01,  1.7017e-01,  4.4773e-01,
#         2.6707e-01,  2.8278e-01, -1.0472e-02,  1.6854e-02,  7.0198e-03,
#         9.1390e-02, -6.5450e-02,  2.4350e-01,  3.3776e-01,  2.3565e-01,
#        -1.0184e-01,  6.0707e-04,  3.1420e-02, -2.0000e-01,  0.0000e+00,
#        -2.0000e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00, -3.6449e-01, -3.4574e-01,
#         1.0700e+00,  1.2540e-01,  1.0621e-01, -1.7668e-02,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00])

# %% [markdown]
# <h1> Hyperparameter tuning </h1>
# Still working on it

# %%
import numpy as np
from sklearn.model_selection import ParameterSampler

param_grid = {
    'policy_size': [(256, 256), (128, 128), (64, 64)],
    'rl_step_size': np.logspace(-4, 0, num=10),
    'learnrate': np.logspace(-4, 0, num=10),
    'entcoeff': np.logspace(-4, 0, num=10),
    'batchsize': [16, 32, 64, 128],
    'num_epoch': [5, 10, 20],
    'vf_hidden_size': [(256, 256), (128, 128), (64, 64)],
    'regcoef': np.logspace(-4, 0, num=10),
    'gamma': np.linspace(0.9, 0.999, num=10),
    'gae_lambda': np.linspace(0.9, 1.0, num=10)
}

n_iter_search = 50  

random_search = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=123))

# %%
#Policy hyperparameters
policy_size = (256, 256)  # Size of the policy network
seed = 123  # Random seed used for reproducibility
rl_step_size = 0.1
learnrate = 0.00025
entcoeff = 0.01
batchsize = 32
num_epoch = 10

#Value Function hyperparameters
vf_hidden_size = (256, 256) # Value Function Network size
seed = 123  # Random seed used for reproducibility
rl_step_size = 0.1
learnrate = 0.00025
entcoeff = 0.01
batchsize = 32
num_epoch = 10
regcoef = 1e-3

#Training hyperparameters
iterations = 1000
gamma = 0.995
gae_lambda = 0.97


# Wrap the environment
e = GymEnv(env)

# %% [markdown]
# <H1>Set Policies </h1>

# %% [markdown]
# <h2> For CenterReachOut: </h2>
#     - <b> The observation dimension </b> is: the sensory information (Time, joint Positions, Joint Velocities, Object Position, Palm Position etc... ) <br>
#     - <b> The action dimension </b> is the output of the Policy NN and represenents the 63 values of muscle actuator intensities
#
# <h2> Display Activations:</h2>
#     - When the code down below will run, it will automatically generate a tensorboard event that registers the Policy Network.

# %%
# Initialize policy and baseline
policy = MLP(e.spec, hidden_sizes=policy_size, seed=seed, init_log_std=0.25, min_log_std=1.0)
baseline = MLPBaseline(e.spec, reg_coef=regcoef, batch_size=batchsize , hidden_sizes=vf_hidden_size, epochs=num_epoch, learn_rate=learnrate)


print(e.spec.observation_dim) #For CenterReachOut-v0: 157 
print(e.spec.action_dim) #For CenterReachOut-v0: 63 

# Initialize NPG/PPO agent
agent = NPG(e, policy, baseline, normalized_step_size=rl_step_size, seed=seed, save_logs=True,ent_coeff=entcoeff ,tensorboard_log="./ppo_objhold_tensorboard/")
# Out:
# 157
# 63

# %% [markdown]
# <h1> Start Training </h1>

# %%
print("========================================")
print("Starting policy learning")
print("========================================")

# Train the agent
train_agent(job_name='.',
            agent=agent,
            seed=seed,
            niter=10000,
            gamma=gamma,
            gae_lambda=gae_lambda,
            sample_mode="trajectories",
            num_traj=96,
            num_samples=0,
            save_freq=10,
            evaluation_rollouts=10)

print("========================================")
print("Job Finished.")
print("========================================")
# Out:
# ========================================
# Starting policy learning
# ========================================
# Reading: logs\log.csv
# Log read from logs\log.csv: had 7291 entries
# Loaded last saved iteration: 7290
# Resuming from an existing job folder ...
# ......................................................................................
# ITERATION : 7291
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:43:50 2024 ] 7291 139.62 124.67 -100000000.00
# ------------------  ------------
# VF_error_after         0.0631298
# VF_error_before        0.458191
# alpha                  1.06994
# delta                  0.1
# env_samples         9530
# eval_score           124.675
# eval_success           0
# iteration           7290
# kl_dist                0.0511002
# num_samples         9530
# rollout_success        0
# running_score        139.62
# rwd_dense              1.39054
# rwd_sparse            -0.102532
# stoc_pol_max         383.315
# stoc_pol_mean        139.62
# stoc_pol_min        -415.253
# stoc_pol_std         217.723
# success_percentage     0
# surr_improvement       0.0711695
# time_VF                6.80301
# time_npg               2.72453
# time_sampling         25.8711
# time_vpg               0.266506
# ------------------  ------------
# ......................................................................................
# ITERATION : 7292
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:44:29 2024 ] 7292 94.09 192.78 139.62
# ------------------  -------------
# VF_error_after          0.0346519
# VF_error_before         0.0729132
# alpha                   1.3636
# delta                   0.1
# env_samples         19103
# eval_score            192.782
# eval_success            0
# iteration            7290
# kl_dist                 0.0515049
# num_samples          9573
# rollout_success         0
# running_score         135.067
# rwd_dense               0.935622
# rwd_sparse             -0.106502
# stoc_pol_max          383.344
# stoc_pol_mean          94.0857
# stoc_pol_min         -366.183
# stoc_pol_std          235.435
# success_percentage      0
# surr_improvement        0.0717333
# time_VF                 6.55741
# time_npg                2.76071
# time_sampling          23.5577
# time_vpg                0.146728
# ------------------  -------------
# ......................................................................................
# ITERATION : 7293
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:45:02 2024 ] 7293 133.62 192.68 139.62
# ------------------  -------------
# VF_error_after          0.0238887
# VF_error_before         0.0543172
# alpha                   1.40784
# delta                   0.1
# env_samples         28662
# eval_score            192.678
# eval_success            0
# iteration            7290
# kl_dist                 0.0488805
# num_samples          9559
# rollout_success         0
# running_score         134.922
# rwd_dense               1.3305
# rwd_sparse             -0.102188
# stoc_pol_max          383.395
# stoc_pol_mean         133.616
# stoc_pol_min         -415.933
# stoc_pol_std          203.294
# success_percentage      0
# surr_improvement        0.0657867
# time_VF                 6.41548
# time_npg                2.45103
# time_sampling          20.33
# time_vpg                0.120403
# ------------------  -------------
# ......................................................................................
# ITERATION : 7294
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:45:34 2024 ] 7294 175.56 192.72 139.62
# ------------------  -------------
# VF_error_after          0.021224
# VF_error_before         0.0273159
# alpha                   1.34649
# delta                   0.1
# env_samples         38205
# eval_score            192.717
# eval_success            0
# iteration            7290
# kl_dist                 0.0495641
# num_samples          9543
# rollout_success         0
# running_score         138.986
# rwd_dense               1.74999
# rwd_sparse             -0.100754
# stoc_pol_max          383.4
# stoc_pol_mean         175.564
# stoc_pol_min         -365.53
# stoc_pol_std          208.161
# success_percentage      0
# surr_improvement        0.0605193
# time_VF                 6.72059
# time_npg                2.45357
# time_sampling          20.1284
# time_vpg                0.108292
# ------------------  -------------
# ......................................................................................
# ITERATION : 7295
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:46:08 2024 ] 7295 149.61 192.72 175.56
# ------------------  -------------
# VF_error_after          0.0216538
# VF_error_before         0.0398118
# alpha                   1.34106
# delta                   0.1
# env_samples         47744
# eval_score            192.719
# eval_success            0
# iteration            7290
# kl_dist                 0.0489766
# num_samples          9539
# rollout_success         0
# running_score         140.049
# rwd_dense               1.49049
# rwd_sparse             -0.103225
# stoc_pol_max          383.424
# stoc_pol_mean         149.615
# stoc_pol_min         -366.618
# stoc_pol_std          212.708
# success_percentage      0
# surr_improvement        0.071032
# time_VF                 6.78224
# time_npg                2.48281
# time_sampling          20.3633
# time_vpg                0.114817
# ------------------  -------------
# ......................................................................................
# ITERATION : 7296
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:46:39 2024 ] 7296 142.08 192.79 175.56
# ------------------  -------------
# VF_error_after          0.021637
# VF_error_before         0.0279353
# alpha                   1.34978
# delta                   0.1
# env_samples         57219
# eval_score            192.786
# eval_success            0
# iteration            7290
# kl_dist                 0.0497448
# num_samples          9475
# rollout_success         0
# running_score         140.252
# rwd_dense               1.41518
# rwd_sparse             -0.103453
# stoc_pol_max          383.432
# stoc_pol_mean         142.084
# stoc_pol_min         -316.528
# stoc_pol_std          206.842
# success_percentage      0
# surr_improvement        0.0918287
# time_VF                 5.99536
# time_npg                2.34761
# time_sampling          19.8948
# time_vpg                0.110681
# ------------------  -------------
# ......................................................................................
# ITERATION : 7297
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:47:11 2024 ] 7297 170.84 194.05 175.56
# ------------------  -------------
# VF_error_after          0.0708234
# VF_error_before         0.205713
# alpha                   1.25616
# delta                   0.1
# env_samples         66684
# eval_score            194.045
# eval_success            0
# iteration            7290
# kl_dist                 0.0509319
# num_samples          9465
# rollout_success         0
# running_score         143.311
# rwd_dense               1.70313
# rwd_sparse             -0.0992383
# stoc_pol_max          383.409
# stoc_pol_mean         170.837
# stoc_pol_min         -454.715
# stoc_pol_std          201.976
# success_percentage      0
# surr_improvement        0.11219
# time_VF                 5.85401
# time_npg                2.36302
# time_sampling          19.8575
# time_vpg                0.114136
# ------------------  -------------
# ......................................................................................
# ITERATION : 7298
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:47:44 2024 ] 7298 160.38 192.84 175.56
# ------------------  -------------
# VF_error_after          0.0302767
# VF_error_before         0.0798776
# alpha                   1.41314
# delta                   0.1
# env_samples         76137
# eval_score            192.836
# eval_success            0
# iteration            7290
# kl_dist                 0.0499087
# num_samples          9453
# rollout_success         0
# running_score         145.017
# rwd_dense               1.59811
# rwd_sparse             -0.101473
# stoc_pol_max          383.405
# stoc_pol_mean         160.377
# stoc_pol_min         -365.565
# stoc_pol_std          219.668
# success_percentage      0
# surr_improvement        0.0759272
# time_VF                 5.90244
# time_npg                2.47472
# time_sampling          20.4947
# time_vpg                0.111739
# ------------------  -------------
# ......................................................................................
# ITERATION : 7299
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:48:16 2024 ] 7299 130.10 193.07 175.56
# ------------------  -------------
# VF_error_after          0.0276234
# VF_error_before         0.054425
# alpha                   1.29561
# delta                   0.1
# env_samples         85661
# eval_score            193.067
# eval_success            0
# iteration            7290
# kl_dist                 0.0499873
# num_samples          9524
# rollout_success         0
# running_score         143.526
# rwd_dense               1.29535
# rwd_sparse             -0.105153
# stoc_pol_max          383.392
# stoc_pol_mean         130.101
# stoc_pol_min         -366.431
# stoc_pol_std          230.189
# success_percentage      0
# surr_improvement        0.076789
# time_VF                 5.98613
# time_npg                2.3573
# time_sampling          20.811
# time_vpg                0.109083
# ------------------  -------------
# ......................................................................................
# ITERATION : 7300
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:48:51 2024 ] 7300 109.51 191.70 175.56
# ------------------  -------------
# VF_error_after          0.0349546
# VF_error_before         0.052023
# alpha                   1.47769
# delta                   0.1
# env_samples         95049
# eval_score            191.699
# eval_success            0
# iteration            7290
# kl_dist                 0.0491633
# num_samples          9388
# rollout_success         0
# running_score         140.125
# rwd_dense               1.08907
# rwd_sparse             -0.106877
# stoc_pol_max          383.981
# stoc_pol_mean         109.515
# stoc_pol_min         -316.828
# stoc_pol_std          230.68
# success_percentage      0
# surr_improvement        0.0610659
# time_VF                 6.32072
# time_npg                2.39291
# time_sampling          20.1084
# time_vpg                0.109467
# ------------------  -------------
# ......................................................................................
# ITERATION : 7301
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:49:23 2024 ] 7301 128.55 191.39 175.56
# ------------------  --------------
# VF_error_after           0.0396136
# VF_error_before          0.0616259
# alpha                    1.37104
# delta                    0.1
# env_samples         104490
# eval_score             191.393
# eval_success             0
# iteration             7290
# kl_dist                  0.0505834
# num_samples           9441
# rollout_success          0
# running_score          138.968
# rwd_dense                1.27988
# rwd_sparse              -0.104434
# stoc_pol_max           383.35
# stoc_pol_mean          128.553
# stoc_pol_min          -316.665
# stoc_pol_std           229.646
# success_percentage       0
# surr_improvement         0.067927
# time_VF                  6.3548
# time_npg                 2.43096
# time_sampling           20.48
# time_vpg                 0.111053
# ------------------  --------------
# ......................................................................................
# ITERATION : 7302
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:49:57 2024 ] 7302 143.52 191.21 175.56
# ------------------  --------------
# VF_error_after           0.0194162
# VF_error_before          0.0403902
# alpha                    1.4101
# delta                    0.1
# env_samples         114027
# eval_score             191.213
# eval_success             0
# iteration             7290
# kl_dist                  0.0489596
# num_samples           9537
# rollout_success          0
# running_score          139.423
# rwd_dense                1.42958
# rwd_sparse              -0.101643
# stoc_pol_max           383.577
# stoc_pol_mean          143.524
# stoc_pol_min          -329.973
# stoc_pol_std           215.982
# success_percentage       0
# surr_improvement         0.0735717
# time_VF                  6.57403
# time_npg                 2.56013
# time_sampling           21.085
# time_vpg                 0.110911
# ------------------  --------------
# ......................................................................................
# ITERATION : 7303
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:50:29 2024 ] 7303 162.67 190.27 175.56
# ------------------  --------------
# VF_error_after           0.0243908
# VF_error_before          0.0972119
# alpha                    1.51387
# delta                    0.1
# env_samples         123480
# eval_score             190.272
# eval_success             0
# iteration             7290
# kl_dist                  0.0493222
# num_samples           9453
# rollout_success          0
# running_score          141.748
# rwd_dense                1.62144
# rwd_sparse              -0.101515
# stoc_pol_max           383.349
# stoc_pol_mean          162.668
# stoc_pol_min          -316.258
# stoc_pol_std           211.784
# success_percentage       0
# surr_improvement         0.0749962
# time_VF                  5.8445
# time_npg                 2.37131
# time_sampling           20.702
# time_vpg                 0.107316
# ------------------  --------------
# ......................................................................................
# ITERATION : 7304
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:51:02 2024 ] 7304 146.74 191.64 175.56
# ------------------  --------------
# VF_error_after           0.0428366
# VF_error_before          0.095738
# alpha                    1.51856
# delta                    0.1
# env_samples         133054
# eval_score             191.637
# eval_success             0
# iteration             7290
# kl_dist                  0.0489442
# num_samples           9574
# rollout_success          0
# running_score          142.247
# rwd_dense                1.46175
# rwd_sparse              -0.103493
# stoc_pol_max           383.374
# stoc_pol_mean          146.741
# stoc_pol_min          -316.652
# stoc_pol_std           214.944
# success_percentage       0
# surr_improvement         0.0678079
# time_VF                  6.2722
# time_npg                 2.41597
# time_sampling           20.237
# time_vpg                 0.122087
# ------------------  --------------
# ......................................................................................
# ITERATION : 7305
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:51:34 2024 ] 7305 129.24 191.66 175.56
# ------------------  --------------
# VF_error_after           0.0171262
# VF_error_before          0.0327022
# alpha                    1.36964
# delta                    0.1
# env_samples         142590
# eval_score             191.658
# eval_success             0
# iteration             7290
# kl_dist                  0.0503014
# num_samples           9536
# rollout_success          0
# running_score          140.947
# rwd_dense                1.28677
# rwd_sparse              -0.105691
# stoc_pol_max           383.348
# stoc_pol_mean          129.243
# stoc_pol_min          -316.78
# stoc_pol_std           230.892
# success_percentage       0
# surr_improvement         0.0707392
# time_VF                  5.9286
# time_npg                 2.45302
# time_sampling           20.1708
# time_vpg                 0.107012
# ------------------  --------------
# ......................................................................................
# ITERATION : 7306
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:52:06 2024 ] 7306 114.57 191.71 175.56
# ------------------  --------------
# VF_error_after           0.0165459
# VF_error_before          0.0363563
# alpha                    1.32921
# delta                    0.1
# env_samples         152097
# eval_score             191.713
# eval_success             0
# iteration             7290
# kl_dist                  0.0481214
# num_samples           9507
# rollout_success          0
# running_score          138.309
# rwd_dense                1.14006
# rwd_sparse              -0.108054
# stoc_pol_max           383.374
# stoc_pol_mean          114.572
# stoc_pol_min          -316.834
# stoc_pol_std           246.156
# success_percentage       0
# surr_improvement         0.0754586
# time_VF                  6.30602
# time_npg                 2.58724
# time_sampling           20.2679
# time_vpg                 0.11394
# ------------------  --------------
# ......................................................................................
# ITERATION : 7307
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:52:38 2024 ] 7307 161.22 191.90 175.56
# ------------------  --------------
# VF_error_after           0.0167388
# VF_error_before          0.0288019
# alpha                    1.33429
# delta                    0.1
# env_samples         161647
# eval_score             191.897
# eval_success             0
# iteration             7290
# kl_dist                  0.0494402
# num_samples           9550
# rollout_success          0
# running_score          140.6
# rwd_dense                1.60651
# rwd_sparse              -0.101241
# stoc_pol_max           383.389
# stoc_pol_mean          161.217
# stoc_pol_min          -316.825
# stoc_pol_std           213.421
# success_percentage       0
# surr_improvement         0.0756688
# time_VF                  5.92078
# time_npg                 2.3889
# time_sampling           20.3211
# time_vpg                 0.107919
# ------------------  --------------
# ......................................................................................
# ITERATION : 7308
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:53:10 2024 ] 7308 138.02 193.22 175.56
# ------------------  --------------
# VF_error_after           0.0167759
# VF_error_before          0.0294436
# alpha                    1.27291
# delta                    0.1
# env_samples         171170
# eval_score             193.218
# eval_success             0
# iteration             7290
# kl_dist                  0.0497878
# num_samples           9523
# rollout_success          0
# running_score          140.342
# rwd_dense                1.37452
# rwd_sparse              -0.103481
# stoc_pol_max           383.37
# stoc_pol_mean          138.018
# stoc_pol_min          -316.691
# stoc_pol_std           223.184
# success_percentage       0
# surr_improvement         0.0766752
# time_VF                  5.8767
# time_npg                 2.46359
# time_sampling           20.3337
# time_vpg                 0.1099
# ------------------  --------------
# ......................................................................................
# ITERATION : 7309
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:53:42 2024 ] 7309 124.46 201.01 175.56
# ------------------  --------------
# VF_error_after           0.037853
# VF_error_before          0.0504784
# alpha                    1.36863
# delta                    0.1
# env_samples         180532
# eval_score             201.01
# eval_success             0
# iteration             7290
# kl_dist                  0.0495963
# num_samples           9362
# rollout_success          0
# running_score          138.753
# rwd_dense                1.23892
# rwd_sparse              -0.10367
# stoc_pol_max           383.376
# stoc_pol_mean          124.458
# stoc_pol_min          -365.46
# stoc_pol_std           213.473
# success_percentage       0
# surr_improvement         0.0728558
# time_VF                  5.92533
# time_npg                 2.30236
# time_sampling           19.8692
# time_vpg                 0.10914
# ------------------  --------------
# ......................................................................................
# ITERATION : 7310
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:54:15 2024 ] 7310 120.19 222.04 175.56
# ------------------  --------------
# VF_error_after           0.0157991
# VF_error_before          0.0256226
# alpha                    1.22968
# delta                    0.1
# env_samples         190016
# eval_score             222.04
# eval_success             0
# iteration             7290
# kl_dist                  0.0494744
# num_samples           9484
# rollout_success          0
# running_score          136.897
# rwd_dense                1.19625
# rwd_sparse              -0.105833
# stoc_pol_max           383.391
# stoc_pol_mean          120.191
# stoc_pol_min          -316.671
# stoc_pol_std           235.877
# success_percentage       0
# surr_improvement         0.166056
# time_VF                  5.91218
# time_npg                 2.34071
# time_sampling           19.9767
# time_vpg                 0.117693
# ------------------  --------------
# ......................................................................................
# ITERATION : 7311
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:54:46 2024 ] 7311 121.19 225.28 175.56
# ------------------  --------------
# VF_error_after           0.041264
# VF_error_before          0.0549443
# alpha                    1.47696
# delta                    0.1
# env_samples         199364
# eval_score             225.284
# eval_success             0
# iteration             7290
# kl_dist                  0.0503428
# num_samples           9348
# rollout_success          0
# running_score          135.326
# rwd_dense                1.20622
# rwd_sparse              -0.104907
# stoc_pol_max           383.415
# stoc_pol_mean          121.188
# stoc_pol_min          -366.307
# stoc_pol_std           228.991
# success_percentage       0
# surr_improvement         0.0624512
# time_VF                  5.84069
# time_npg                 2.39872
# time_sampling           19.9275
# time_vpg                 0.114377
# ------------------  --------------
# ......................................................................................
# ITERATION : 7312
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:55:18 2024 ] 7312 80.25 159.17 175.56
# ------------------  --------------
# VF_error_after           0.0345033
# VF_error_before          0.0568713
# alpha                    1.48172
# delta                    0.1
# env_samples         208838
# eval_score             159.168
# eval_success             0
# iteration             7290
# kl_dist                  0.0507873
# num_samples           9474
# rollout_success          0
# running_score          129.819
# rwd_dense                0.79686
# rwd_sparse              -0.108792
# stoc_pol_max           383.368
# stoc_pol_mean           80.2517
# stoc_pol_min          -366.513
# stoc_pol_std           241.353
# success_percentage       0
# surr_improvement         0.0642231
# time_VF                  5.81311
# time_npg                 2.34392
# time_sampling           19.9332
# time_vpg                 0.111712
# ------------------  --------------
# ......................................................................................
# ITERATION : 7313
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:55:49 2024 ] 7313 134.42 160.22 175.56
# ------------------  --------------
# VF_error_after           0.0271312
# VF_error_before          0.0379846
# alpha                    1.45928
# delta                    0.1
# env_samples         218346
# eval_score             160.221
# eval_success             0
# iteration             7290
# kl_dist                  0.0490872
# num_samples           9508
# rollout_success          0
# running_score          130.279
# rwd_dense                1.33895
# rwd_sparse              -0.104381
# stoc_pol_max           383.401
# stoc_pol_mean          134.419
# stoc_pol_min          -366.002
# stoc_pol_std           240.361
# success_percentage       0
# surr_improvement         0.0684161
# time_VF                  5.87313
# time_npg                 2.31698
# time_sampling           19.9821
# time_vpg                 0.103021
# ------------------  --------------
# ......................................................................................
# ITERATION : 7314
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:56:21 2024 ] 7314 109.30 182.30 175.56
# ------------------  --------------
# VF_error_after           0.0212559
# VF_error_before          0.0344733
# alpha                    1.572
# delta                    0.1
# env_samples         227846
# eval_score             182.3
# eval_success             0
# iteration             7290
# kl_dist                  0.0494054
# num_samples           9500
# rollout_success          0
# running_score          128.181
# rwd_dense                1.08775
# rwd_sparse              -0.106754
# stoc_pol_max           383.352
# stoc_pol_mean          109.299
# stoc_pol_min          -316.428
# stoc_pol_std           241.577
# success_percentage       0
# surr_improvement         0.0632854
# time_VF                  6.21891
# time_npg                 2.34813
# time_sampling           20.4286
# time_vpg                 0.104942
# ------------------  --------------
# ......................................................................................
# ITERATION : 7315
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:56:52 2024 ] 7315 106.45 162.28 175.56
# ------------------  --------------
# VF_error_after           0.0196179
# VF_error_before          0.0398295
# alpha                    1.36333
# delta                    0.1
# env_samples         237320
# eval_score             162.281
# eval_success             0
# iteration             7290
# kl_dist                  0.0499517
# num_samples           9474
# rollout_success          0
# running_score          126.007
# rwd_dense                1.05923
# rwd_sparse              -0.1075
# stoc_pol_max           383.422
# stoc_pol_mean          106.446
# stoc_pol_min          -316.584
# stoc_pol_std           246.764
# success_percentage       0
# surr_improvement         0.0821257
# time_VF                  6.05307
# time_npg                 2.31996
# time_sampling           20.0149
# time_vpg                 0.111089
# ------------------  --------------
# ......................................................................................
# ITERATION : 7316
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:57:24 2024 ] 7316 145.46 212.44 175.56
# ------------------  --------------
# VF_error_after           0.0323206
# VF_error_before          0.0455931
# alpha                    1.56949
# delta                    0.1
# env_samples         246642
# eval_score             212.438
# eval_success             0
# iteration             7290
# kl_dist                  0.0496613
# num_samples           9322
# rollout_success          0
# running_score          127.953
# rwd_dense                1.44899
# rwd_sparse              -0.103489
# stoc_pol_max           383.413
# stoc_pol_mean          145.464
# stoc_pol_min          -316.85
# stoc_pol_std           227.998
# success_percentage       0
# surr_improvement         0.0591883
# time_VF                  5.81528
# time_npg                 2.42641
# time_sampling           20.0404
# time_vpg                 0.107634
# ------------------  --------------
# ......................................................................................
# ITERATION : 7317
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:57:55 2024 ] 7317 151.24 212.72 175.56
# ------------------  --------------
# VF_error_after           0.0133677
# VF_error_before          0.0275551
# alpha                    1.41394
# delta                    0.1
# env_samples         256078
# eval_score             212.715
# eval_success             0
# iteration             7290
# kl_dist                  0.0494947
# num_samples           9436
# rollout_success          0
# running_score          130.281
# rwd_dense                1.50671
# rwd_sparse              -0.10397
# stoc_pol_max           383.364
# stoc_pol_mean          151.237
# stoc_pol_min          -366.109
# stoc_pol_std           242.582
# success_percentage       0
# surr_improvement         0.0710984
# time_VF                  5.85029
# time_npg                 2.55615
# time_sampling           19.6911
# time_vpg                 0.122239
# ------------------  --------------
# ......................................................................................
# ITERATION : 7318
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:58:26 2024 ] 7318 144.62 216.67 175.56
# ------------------  --------------
# VF_error_after           0.0235027
# VF_error_before          0.0400701
# alpha                    1.46277
# delta                    0.1
# env_samples         265401
# eval_score             216.674
# eval_success             0
# iteration             7290
# kl_dist                  0.0492432
# num_samples           9323
# rollout_success          0
# running_score          131.715
# rwd_dense                1.44051
# rwd_sparse              -0.101298
# stoc_pol_max           383.796
# stoc_pol_mean          144.617
# stoc_pol_min          -316.776
# stoc_pol_std           218.54
# success_percentage       0
# surr_improvement         0.0617492
# time_VF                  5.94285
# time_npg                 2.46884
# time_sampling           19.8815
# time_vpg                 0.109775
# ------------------  --------------
# ......................................................................................
# ITERATION : 7319
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:58:58 2024 ] 7319 128.28 215.17 175.56
# ------------------  --------------
# VF_error_after           0.0149516
# VF_error_before          0.0383841
# alpha                    1.36768
# delta                    0.1
# env_samples         275001
# eval_score             215.174
# eval_success             0
# iteration             7290
# kl_dist                  0.049085
# num_samples           9600
# rollout_success          0
# running_score          131.372
# rwd_dense                1.27718
# rwd_sparse              -0.105317
# stoc_pol_max           383.382
# stoc_pol_mean          128.284
# stoc_pol_min          -316.596
# stoc_pol_std           234.349
# success_percentage       0
# surr_improvement         0.0695804
# time_VF                  6.24052
# time_npg                 2.33571
# time_sampling           20.2195
# time_vpg                 0.111301
# ------------------  --------------
# ......................................................................................
# ITERATION : 7320
# Performing evaluation rollouts ........
# [ Sun Jun 16 02:59:31 2024 ] 7320 136.34 224.26 175.56
# ------------------  --------------
# VF_error_after           0.0191206
# VF_error_before          0.0417129
# alpha                    1.44004
# delta                    0.1
# env_samples         284397
# eval_score             224.262
# eval_success             0
# iteration             7290
# kl_dist                  0.0509517
# num_samples           9396
# rollout_success          0
# running_score          131.868
# rwd_dense                1.3577
# rwd_sparse              -0.104617
# stoc_pol_max           383.384
# stoc_pol_mean          136.336
# stoc_pol_min          -316.817
# stoc_pol_std           214.283
# success_percentage       0
# surr_improvement         0.0644711
# time_VF                  5.90982
# time_npg                 2.29765
# time_sampling           19.5567
# time_vpg                 0.110758
# ------------------  --------------
# ......................................................................................
# ITERATION : 7321
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:00:02 2024 ] 7321 134.93 190.80 175.56
# ------------------  --------------
# VF_error_after           0.0161143
# VF_error_before          0.0384456
# alpha                    1.46092
# delta                    0.1
# env_samples         293878
# eval_score             190.801
# eval_success             0
# iteration             7290
# kl_dist                  0.050535
# num_samples           9481
# rollout_success          0
# running_score          132.174
# rwd_dense                1.34403
# rwd_sparse              -0.104323
# stoc_pol_max           383.388
# stoc_pol_mean          134.927
# stoc_pol_min          -316.557
# stoc_pol_std           242.79
# success_percentage       0
# surr_improvement         0.0648979
# time_VF                  6.24703
# time_npg                 2.30061
# time_sampling           19.8822
# time_vpg                 0.10468
# ------------------  --------------
# ......................................................................................
# ITERATION : 7322
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:00:34 2024 ] 7322 121.17 199.15 175.56
# ------------------  --------------
# VF_error_after           0.0279432
# VF_error_before          0.0507068
# alpha                    1.32483
# delta                    0.1
# env_samples         303371
# eval_score             199.148
# eval_success             0
# iteration             7290
# kl_dist                  0.0499319
# num_samples           9493
# rollout_success          0
# running_score          131.074
# rwd_dense                1.20603
# rwd_sparse              -0.107466
# stoc_pol_max           383.368
# stoc_pol_mean          121.169
# stoc_pol_min          -316.689
# stoc_pol_std           230.757
# success_percentage       0
# surr_improvement         0.0677303
# time_VF                  5.85562
# time_npg                 2.31311
# time_sampling           19.9013
# time_vpg                 0.106168
# ------------------  --------------
# ......................................................................................
# ITERATION : 7323
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:01:05 2024 ] 7323 113.69 193.24 175.56
# ------------------  --------------
# VF_error_after           0.0229824
# VF_error_before          0.0483542
# alpha                    1.38215
# delta                    0.1
# env_samples         312940
# eval_score             193.241
# eval_success             0
# iteration             7290
# kl_dist                  0.0500467
# num_samples           9569
# rollout_success          0
# running_score          129.335
# rwd_dense                1.13124
# rwd_sparse              -0.106328
# stoc_pol_max           383.406
# stoc_pol_mean          113.69
# stoc_pol_min          -316.686
# stoc_pol_std           231.358
# success_percentage       0
# surr_improvement         0.0669013
# time_VF                  5.95071
# time_npg                 2.33286
# time_sampling           19.9089
# time_vpg                 0.110153
# ------------------  --------------
# ......................................................................................
# ITERATION : 7324
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:01:36 2024 ] 7324 162.07 242.88 175.56
# ------------------  --------------
# VF_error_after           0.0257046
# VF_error_before          0.0415367
# alpha                    1.37266
# delta                    0.1
# env_samples         322356
# eval_score             242.885
# eval_success             0
# iteration             7290
# kl_dist                  0.050733
# num_samples           9416
# rollout_success          0
# running_score          132.608
# rwd_dense                1.615
# rwd_sparse              -0.103682
# stoc_pol_max           383.583
# stoc_pol_mean          162.066
# stoc_pol_min          -316.872
# stoc_pol_std           241.141
# success_percentage       0
# surr_improvement         0.0677505
# time_VF                  5.79777
# time_npg                 2.42295
# time_sampling           19.7565
# time_vpg                 0.10461
# ------------------  --------------
# ......................................................................................
# ITERATION : 7325
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:02:08 2024 ] 7325 145.76 253.46 175.56
# ------------------  --------------
# VF_error_after           0.0112461
# VF_error_before          0.0326259
# alpha                    1.59427
# delta                    0.1
# env_samples         331864
# eval_score             253.463
# eval_success             0
# iteration             7290
# kl_dist                  0.050197
# num_samples           9508
# rollout_success          0
# running_score          133.924
# rwd_dense                1.45199
# rwd_sparse              -0.103404
# stoc_pol_max           383.331
# stoc_pol_mean          145.765
# stoc_pol_min          -366.446
# stoc_pol_std           225.446
# success_percentage       0
# surr_improvement         0.0602305
# time_VF                  6.18289
# time_npg                 2.40756
# time_sampling           20.0538
# time_vpg                 0.124065
# ------------------  --------------
# ......................................................................................
# ITERATION : 7326
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:02:40 2024 ] 7326 134.44 228.55 175.56
# ------------------  --------------
# VF_error_after           0.0178142
# VF_error_before          0.0306831
# alpha                    1.31913
# delta                    0.1
# env_samples         341347
# eval_score             228.547
# eval_success             0
# iteration             7290
# kl_dist                  0.048249
# num_samples           9483
# rollout_success          0
# running_score          133.976
# rwd_dense                1.33879
# rwd_sparse              -0.102661
# stoc_pol_max           383.428
# stoc_pol_mean          134.445
# stoc_pol_min          -316.789
# stoc_pol_std           229.332
# success_percentage       0
# surr_improvement         0.075091
# time_VF                  6.03998
# time_npg                 2.32042
# time_sampling           19.8277
# time_vpg                 0.110117
# ------------------  --------------
# ......................................................................................
# ITERATION : 7327
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:03:11 2024 ] 7327 174.85 238.43 175.56
# ------------------  --------------
# VF_error_after           0.0089868
# VF_error_before          0.0271998
# alpha                    1.30661
# delta                    0.1
# env_samples         350898
# eval_score             238.426
# eval_success             0
# iteration             7290
# kl_dist                  0.0493973
# num_samples           9551
# rollout_success          0
# running_score          138.063
# rwd_dense                1.74281
# rwd_sparse              -0.0990684
# stoc_pol_max           383.387
# stoc_pol_mean          174.847
# stoc_pol_min          -365.974
# stoc_pol_std           214.146
# success_percentage       0
# surr_improvement         0.0742418
# time_VF                  5.96699
# time_npg                 2.32603
# time_sampling           19.9099
# time_vpg                 0.110898
# ------------------  --------------
# ......................................................................................
# ITERATION : 7328
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:03:43 2024 ] 7328 148.85 217.96 175.56
# ------------------  ---------------
# VF_error_after           0.00998257
# VF_error_before          0.0141689
# alpha                    1.34771
# delta                    0.1
# env_samples         360411
# eval_score             217.965
# eval_success             0
# iteration             7290
# kl_dist                  0.0494403
# num_samples           9513
# rollout_success          0
# running_score          139.142
# rwd_dense                1.48283
# rwd_sparse              -0.102528
# stoc_pol_max           383.423
# stoc_pol_mean          148.849
# stoc_pol_min          -316.544
# stoc_pol_std           231.081
# success_percentage       0
# surr_improvement         0.0668266
# time_VF                  5.93668
# time_npg                 2.52919
# time_sampling           19.8678
# time_vpg                 0.109987
# ------------------  ---------------
# ......................................................................................
# ITERATION : 7329
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:04:14 2024 ] 7329 170.82 235.66 175.56
# ------------------  ---------------
# VF_error_after           0.00784187
# VF_error_before          0.0144433
# alpha                    1.40006
# delta                    0.1
# env_samples         369806
# eval_score             235.662
# eval_success             0
# iteration             7290
# kl_dist                  0.0489265
# num_samples           9395
# rollout_success          0
# running_score          142.31
# rwd_dense                1.70255
# rwd_sparse              -0.10026
# stoc_pol_max           383.334
# stoc_pol_mean          170.821
# stoc_pol_min          -316.655
# stoc_pol_std           219.13
# success_percentage       0
# surr_improvement         0.0617107
# time_VF                  5.79076
# time_npg                 2.44635
# time_sampling           20.1854
# time_vpg                 0.116026
# ------------------  ---------------
# ......................................................................................
# ITERATION : 7330
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:04:47 2024 ] 7330 140.73 226.49 175.56
# ------------------  --------------
# VF_error_after           0.0111066
# VF_error_before          0.0210627
# alpha                    1.27733
# delta                    0.1
# env_samples         379271
# eval_score             226.491
# eval_success             0
# iteration             7290
# kl_dist                  0.0494983
# num_samples           9465
# rollout_success          0
# running_score          142.152
# rwd_dense                1.40167
# rwd_sparse              -0.102465
# stoc_pol_max           383.414
# stoc_pol_mean          140.733
# stoc_pol_min          -365.313
# stoc_pol_std           226.579
# success_percentage       0
# surr_improvement         0.0707989
# time_VF                  5.80049
# time_npg                 2.29412
# time_sampling           19.8999
# time_vpg                 0.106707
# ------------------  --------------
# ......................................................................................
# ITERATION : 7331
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:05:19 2024 ] 7331 109.06 218.87 175.56
# ------------------  --------------
# VF_error_after           0.0140492
# VF_error_before          0.0293214
# alpha                    1.30695
# delta                    0.1
# env_samples         388827
# eval_score             218.868
# eval_success             0
# iteration             7290
# kl_dist                  0.0494851
# num_samples           9556
# rollout_success          0
# running_score          138.843
# rwd_dense                1.08497
# rwd_sparse              -0.108342
# stoc_pol_max           383.244
# stoc_pol_mean          109.063
# stoc_pol_min          -316.686
# stoc_pol_std           246.095
# success_percentage       0
# surr_improvement         0.0652963
# time_VF                  5.93469
# time_npg                 2.34017
# time_sampling           20.0398
# time_vpg                 0.103846
# ------------------  --------------
# ......................................................................................
# ITERATION : 7332
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:05:50 2024 ] 7332 172.16 219.69 175.56
# ------------------  --------------
# VF_error_after           0.0273039
# VF_error_before          0.0449235
# alpha                    1.59867
# delta                    0.1
# env_samples         398234
# eval_score             219.69
# eval_success             0
# iteration             7290
# kl_dist                  0.0497378
# num_samples           9407
# rollout_success          0
# running_score          142.174
# rwd_dense                1.7159
# rwd_sparse              -0.100396
# stoc_pol_max           383.386
# stoc_pol_mean          172.156
# stoc_pol_min          -316.555
# stoc_pol_std           209.452
# success_percentage       0
# surr_improvement         0.060339
# time_VF                  5.96433
# time_npg                 2.30779
# time_sampling           19.7302
# time_vpg                 0.108487
# ------------------  --------------
# ......................................................................................
# ITERATION : 7333
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:06:22 2024 ] 7333 164.06 240.00 175.56
# ------------------  ---------------
# VF_error_after           0.00816374
# VF_error_before          0.019194
# alpha                    1.35246
# delta                    0.1
# env_samples         407785
# eval_score             240.003
# eval_success             0
# iteration             7290
# kl_dist                  0.0493076
# num_samples           9551
# rollout_success          0
# running_score          144.362
# rwd_dense                1.63489
# rwd_sparse              -0.101393
# stoc_pol_max           383.322
# stoc_pol_mean          164.055
# stoc_pol_min          -366.429
# stoc_pol_std           226.999
# success_percentage       0
# surr_improvement         0.0659205
# time_VF                  5.88959
# time_npg                 2.3824
# time_sampling           20.3433
# time_vpg                 0.1068
# ------------------  ---------------
# ......................................................................................
# ITERATION : 7334
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:06:53 2024 ] 7334 163.78 237.37 175.56
# ------------------  --------------
# VF_error_after           0.0278235
# VF_error_before          0.0382723
# alpha                    1.52053
# delta                    0.1
# env_samples         417132
# eval_score             237.375
# eval_success             0
# iteration             7290
# kl_dist                  0.049873
# num_samples           9347
# rollout_success          0
# running_score          146.304
# rwd_dense                1.63211
# rwd_sparse              -0.102086
# stoc_pol_max           383.454
# stoc_pol_mean          163.777
# stoc_pol_min          -316.552
# stoc_pol_std           242.457
# success_percentage       0
# surr_improvement         0.0623701
# time_VF                  5.8837
# time_npg                 2.39076
# time_sampling           19.5852
# time_vpg                 0.105937
# ------------------  --------------
# ......................................................................................
# ITERATION : 7335
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:07:24 2024 ] 7335 123.53 244.13 175.56
# ------------------  --------------
# VF_error_after           0.0295225
# VF_error_before          0.0491047
# alpha                    1.49568
# delta                    0.1
# env_samples         426462
# eval_score             244.13
# eval_success             0
# iteration             7290
# kl_dist                  0.0483525
# num_samples           9330
# rollout_success          0
# running_score          144.026
# rwd_dense                1.23004
# rwd_sparse              -0.105374
# stoc_pol_max           383.345
# stoc_pol_mean          123.528
# stoc_pol_min          -366.564
# stoc_pol_std           253.694
# success_percentage       0
# surr_improvement         0.0602725
# time_VF                  5.78405
# time_npg                 2.38956
# time_sampling           19.5289
# time_vpg                 0.113249
# ------------------  --------------
# ......................................................................................
# ITERATION : 7336
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:07:55 2024 ] 7336 137.60 244.16 175.56
# ------------------  --------------
# VF_error_after           0.0122347
# VF_error_before          0.0214644
# alpha                    1.35946
# delta                    0.1
# env_samples         435830
# eval_score             244.156
# eval_success             0
# iteration             7290
# kl_dist                  0.0503766
# num_samples           9368
# rollout_success          0
# running_score          143.384
# rwd_dense                1.37038
# rwd_sparse              -0.10272
# stoc_pol_max           383.418
# stoc_pol_mean          137.604
# stoc_pol_min          -316.646
# stoc_pol_std           230.895
# success_percentage       0
# surr_improvement         0.0719368
# time_VF                  5.92925
# time_npg                 2.36403
# time_sampling           19.4208
# time_vpg                 0.107471
# ------------------  --------------
# ......................................................................................
# ITERATION : 7337
# Performing evaluation rollouts ........
# [ Sun Jun 16 03:08:27 2024 ] 7337 152.06 237.39 175.56
# ------------------  --------------
# VF_error_after           0.0259211
# VF_error_before          0.0478996
# alpha                    1.61248
# delta                    0.1
# env_samples         445238
# eval_score             237.393
# eval_success             0
# iteration             7290
# kl_dist                  0.0495218
# num_samples           9408
# rollout_success          0
# running_score          144.252
# rwd_dense                1.51499
# rwd_sparse              -0.101057
# stoc_pol_max           383.33
# stoc_pol_mean          152.065
# stoc_pol_min          -366.276
# stoc_pol_std           215.559
# success_percentage       0
# surr_improvement         0.0568606
# time_VF                  6.04584
# time_npg                 2.31712
# time_sampling           19.9512
# time_vpg                 0.106734
# ------------------  --------------
# ......................................................................................
# ITERATION : 7338
# ...
# time_vpg               0.112284
# ------------------  --------------
# ......................................................................................
# ITERATION : 8862
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:49:12 2024 ] 8862 159.04 255.21 255.32
# ------------------  --------------
# VF_error_after         0.000245513
# VF_error_before        0.00102662
# alpha                  1.25128
# delta                  0.1
# env_samples            1.50301e+07
# eval_score           255.211
# eval_success           0
# iteration           7290
# kl_dist                0.0499772
# num_samples         9600
# rollout_success        0
# running_score        169.596
# rwd_dense              1.58472
# rwd_sparse            -0.104656
# stoc_pol_max         383.404
# stoc_pol_mean        159.038
# stoc_pol_min        -267.25
# stoc_pol_std         232.149
# success_percentage     0
# surr_improvement       0.069984
# time_VF                6.12116
# time_npg               2.43153
# time_sampling         20.6443
# time_vpg               0.111866
# ------------------  --------------
# ......................................................................................
# ITERATION : 8863
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:49:45 2024 ] 8863 158.57 252.50 255.32
# ------------------  --------------
# VF_error_after         0.00596756
# VF_error_before        0.00895959
# alpha                  1.59049
# delta                  0.1
# env_samples            1.50397e+07
# eval_score           252.5
# eval_success           0
# iteration           7290
# kl_dist                0.050292
# num_samples         9533
# rollout_success        0
# running_score        168.494
# rwd_dense              1.58008
# rwd_sparse            -0.10533
# stoc_pol_max         383.47
# stoc_pol_mean        158.574
# stoc_pol_min        -267.467
# stoc_pol_std         236.384
# success_percentage     0
# surr_improvement       0.0419661
# time_VF                6.05352
# time_npg               2.38029
# time_sampling         20.6446
# time_vpg               0.106534
# ------------------  --------------
# ......................................................................................
# ITERATION : 8864
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:50:19 2024 ] 8864 182.57 249.07 255.32
# ------------------  --------------
# VF_error_after         0.000717167
# VF_error_before        0.00217932
# alpha                  1.43464
# delta                  0.1
# env_samples            1.50493e+07
# eval_score           249.072
# eval_success           0
# iteration           7290
# kl_dist                0.0496592
# num_samples         9600
# rollout_success        0
# running_score        169.901
# rwd_dense              1.82004
# rwd_sparse            -0.101629
# stoc_pol_max         383.375
# stoc_pol_mean        182.57
# stoc_pol_min        -267.478
# stoc_pol_std         221.727
# success_percentage     0
# surr_improvement       0.0622148
# time_VF                6.22421
# time_npg               2.42741
# time_sampling         21.4559
# time_vpg               0.105428
# ------------------  --------------
# ......................................................................................
# ITERATION : 8865
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:50:52 2024 ] 8865 168.20 251.87 255.32
# ------------------  --------------
# VF_error_after         0.00426144
# VF_error_before        0.00565872
# alpha                  1.77031
# delta                  0.1
# env_samples            1.50588e+07
# eval_score           251.867
# eval_success           0
# iteration           7290
# kl_dist                0.0503686
# num_samples         9545
# rollout_success        0
# running_score        169.732
# rwd_dense              1.67638
# rwd_sparse            -0.102959
# stoc_pol_max         383.535
# stoc_pol_mean        168.204
# stoc_pol_min        -267.656
# stoc_pol_std         227.438
# success_percentage     0
# surr_improvement       0.0428365
# time_VF                6.08042
# time_npg               2.39606
# time_sampling         20.538
# time_vpg               0.110777
# ------------------  --------------
# ......................................................................................
# ITERATION : 8866
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:51:24 2024 ] 8866 184.56 237.02 255.32
# ------------------  --------------
# VF_error_after         0.00453036
# VF_error_before        0.0089408
# alpha                  1.79714
# delta                  0.1
# env_samples            1.50684e+07
# eval_score           237.02
# eval_success           0
# iteration           7290
# kl_dist                0.0497603
# num_samples         9578
# rollout_success        0
# running_score        171.215
# rwd_dense              1.83998
# rwd_sparse            -0.102296
# stoc_pol_max         383.403
# stoc_pol_mean        184.564
# stoc_pol_min        -267.495
# stoc_pol_std         234.012
# success_percentage     0
# surr_improvement       0.0468512
# time_VF                6.17292
# time_npg               2.42227
# time_sampling         20.5568
# time_vpg               0.108486
# ------------------  --------------
# ......................................................................................
# ITERATION : 8867
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:51:57 2024 ] 8867 163.45 248.01 255.32
# ------------------  --------------
# VF_error_after         0.00880705
# VF_error_before        0.0123574
# alpha                  1.77777
# delta                  0.1
# env_samples            1.50779e+07
# eval_score           248.013
# eval_success           0
# iteration           7290
# kl_dist                0.0505639
# num_samples         9462
# rollout_success        0
# running_score        170.438
# rwd_dense              1.62879
# rwd_sparse            -0.102322
# stoc_pol_max         383.472
# stoc_pol_mean        163.445
# stoc_pol_min        -267.34
# stoc_pol_std         226.933
# success_percentage     0
# surr_improvement       0.0486911
# time_VF                6.02854
# time_npg               2.36352
# time_sampling         20.3833
# time_vpg               0.10116
# ------------------  --------------
# ......................................................................................
# ITERATION : 8868
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:52:30 2024 ] 8868 166.27 252.37 255.32
# ------------------  --------------
# VF_error_after         0.00649403
# VF_error_before        0.00933678
# alpha                  1.5023
# delta                  0.1
# env_samples            1.50874e+07
# eval_score           252.374
# eval_success           0
# iteration           7290
# kl_dist                0.0492411
# num_samples         9534
# rollout_success        0
# running_score        170.021
# rwd_dense              1.65706
# rwd_sparse            -0.103527
# stoc_pol_max         383.503
# stoc_pol_mean        166.272
# stoc_pol_min        -316.697
# stoc_pol_std         238.656
# success_percentage     0
# surr_improvement       0.0550784
# time_VF                6.16253
# time_npg               2.39856
# time_sampling         20.8583
# time_vpg               0.137273
# ------------------  --------------
# ......................................................................................
# ITERATION : 8869
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:53:04 2024 ] 8869 171.34 247.13 255.32
# ------------------  -------------
# VF_error_after         0.0006838
# VF_error_before        0.00310622
# alpha                  1.52963
# delta                  0.1
# env_samples            1.5097e+07
# eval_score           247.132
# eval_success           0
# iteration           7290
# kl_dist                0.0497454
# num_samples         9600
# rollout_success        0
# running_score        170.153
# rwd_dense              1.7077
# rwd_sparse            -0.1023
# stoc_pol_max         383.527
# stoc_pol_mean        171.336
# stoc_pol_min        -267.496
# stoc_pol_std         218.486
# success_percentage     0
# surr_improvement       0.0666799
# time_VF                6.32033
# time_npg               2.52519
# time_sampling         21.3869
# time_vpg               0.116357
# ------------------  -------------
# ......................................................................................
# ITERATION : 8870
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:53:39 2024 ] 8870 163.08 254.31 255.32
# ------------------  --------------
# VF_error_after         0.00910266
# VF_error_before        0.0175674
# alpha                  1.66264
# delta                  0.1
# env_samples            1.51065e+07
# eval_score           254.306
# eval_success           0
# iteration           7290
# kl_dist                0.0497078
# num_samples         9558
# rollout_success        0
# running_score        169.446
# rwd_dense              1.62514
# rwd_sparse            -0.102553
# stoc_pol_max         383.468
# stoc_pol_mean        163.08
# stoc_pol_min        -267.45
# stoc_pol_std         223.567
# success_percentage     0
# surr_improvement       0.0460972
# time_VF                6.14779
# time_npg               2.42075
# time_sampling         20.8907
# time_vpg               0.116324
# ------------------  --------------
# ......................................................................................
# ITERATION : 8871
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:54:13 2024 ] 8871 152.14 252.67 255.32
# ------------------  --------------
# VF_error_after         0.0459537
# VF_error_before        0.238757
# alpha                  1.50146
# delta                  0.1
# env_samples            1.51161e+07
# eval_score           252.674
# eval_success           0
# iteration           7290
# kl_dist                0.0484279
# num_samples         9600
# rollout_success        0
# running_score        167.715
# rwd_dense              1.51573
# rwd_sparse            -0.10552
# stoc_pol_max         383.523
# stoc_pol_mean        152.139
# stoc_pol_min        -667.986
# stoc_pol_std         252.337
# success_percentage     0
# surr_improvement       0.048079
# time_VF                6.63585
# time_npg               2.51531
# time_sampling         21.2096
# time_vpg               0.116211
# ------------------  --------------
# ......................................................................................
# ITERATION : 8872
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:54:47 2024 ] 8872 193.14 257.20 255.32
# ------------------  --------------
# VF_error_after         0.0106084
# VF_error_before        0.0392602
# alpha                  1.46473
# delta                  0.1
# env_samples            1.51257e+07
# eval_score           257.198
# eval_success           0
# iteration           7290
# kl_dist                0.0495559
# num_samples         9600
# rollout_success        0
# running_score        170.258
# rwd_dense              1.9262
# rwd_sparse            -0.0998402
# stoc_pol_max         383.412
# stoc_pol_mean        193.144
# stoc_pol_min        -316.67
# stoc_pol_std         210.438
# success_percentage     0
# surr_improvement       0.0752554
# time_VF                6.32438
# time_npg               2.5662
# time_sampling         21.3794
# time_vpg               0.116238
# ------------------  --------------
# ......................................................................................
# ITERATION : 8873
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:55:20 2024 ] 8873 169.55 254.73 255.32
# ------------------  --------------
# VF_error_after         0.00569699
# VF_error_before        0.0150638
# alpha                  1.66026
# delta                  0.1
# env_samples            1.51353e+07
# eval_score           254.734
# eval_success           0
# iteration           7290
# kl_dist                0.0499592
# num_samples         9600
# rollout_success        0
# running_score        170.187
# rwd_dense              1.69028
# rwd_sparse            -0.102636
# stoc_pol_max         383.379
# stoc_pol_mean        169.552
# stoc_pol_min        -267.317
# stoc_pol_std         229.998
# success_percentage     0
# surr_improvement       0.0626302
# time_VF                6.14351
# time_npg               2.43744
# time_sampling         20.5861
# time_vpg               0.115843
# ------------------  --------------
# ......................................................................................
# ITERATION : 8874
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:55:53 2024 ] 8874 171.37 246.24 255.32
# ------------------  --------------
# VF_error_after         0.00698493
# VF_error_before        0.0130277
# alpha                  1.55252
# delta                  0.1
# env_samples            1.51449e+07
# eval_score           246.235
# eval_success           0
# iteration           7290
# kl_dist                0.0486509
# num_samples         9531
# rollout_success        0
# running_score        170.305
# rwd_dense              1.708
# rwd_sparse            -0.104089
# stoc_pol_max         383.477
# stoc_pol_mean        171.367
# stoc_pol_min        -267.703
# stoc_pol_std         229.539
# success_percentage     0
# surr_improvement       0.0499063
# time_VF                6.08619
# time_npg               2.43035
# time_sampling         20.4124
# time_vpg               0.11196
# ------------------  --------------
# ......................................................................................
# ITERATION : 8875
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:56:26 2024 ] 8875 170.32 245.34 255.32
# ------------------  --------------
# VF_error_after         0.0154975
# VF_error_before        0.0324957
# alpha                  1.47465
# delta                  0.1
# env_samples            1.51543e+07
# eval_score           245.344
# eval_success           0
# iteration           7290
# kl_dist                0.0491045
# num_samples         9393
# rollout_success        0
# running_score        170.306
# rwd_dense              1.69753
# rwd_sparse            -0.103439
# stoc_pol_max         383.445
# stoc_pol_mean        170.319
# stoc_pol_min        -267.325
# stoc_pol_std         226.514
# success_percentage     0
# surr_improvement       0.0574537
# time_VF                6.01004
# time_npg               2.44597
# time_sampling         20.9214
# time_vpg               0.110242
# ------------------  --------------
# ......................................................................................
# ITERATION : 8876
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:56:59 2024 ] 8876 164.68 239.73 255.32
# ------------------  --------------
# VF_error_after         0.00773371
# VF_error_before        0.0131707
# alpha                  1.51661
# delta                  0.1
# env_samples            1.51638e+07
# eval_score           239.733
# eval_success           0
# iteration           7290
# kl_dist                0.0482212
# num_samples         9530
# rollout_success        0
# running_score        169.744
# rwd_dense              1.64154
# rwd_sparse            -0.104345
# stoc_pol_max         383.426
# stoc_pol_mean        164.678
# stoc_pol_min        -316.823
# stoc_pol_std         234.517
# success_percentage     0
# surr_improvement       0.0514854
# time_VF                6.06886
# time_npg               2.43193
# time_sampling         20.6837
# time_vpg               0.106987
# ------------------  --------------
# ......................................................................................
# ITERATION : 8877
# Performing evaluation rollouts ........
# [ Sun Jun 16 16:57:31 2024 ] 8877 159.94 241.35 255.32
# ------------------  --------------
# VF_error_after         0.000464208
# VF_error_before        0.00214505
# alpha                  1.33342
# delta                  0.1
# env_samples            1.51734e+07
# eval_score           241.352
# eval_success           0
# iteration           7290
# kl_dist                0.0490988
# num_samples         9600
# rollout_success        0
# running_score        168.763
# rwd_dense              1.59371
# rwd_sparse            -0.104001
# stoc_pol_max         383.447
# stoc_pol_mean        159.937
# stoc_pol_min        -316.914
# stoc_pol_std         234.963
# success_percentage     0
# surr_improvement       0.0746265
# time_VF                6.16648
# time_npg               2.42885
# time_sampling         20.5385
# time_vpg               0.109131
# ------------------  --------------
# ......................................................................................
# ITERATION : 8878

# %% [markdown]
# <h1> Logging hyperparameters

# %%
# Data to be written into the file
data = f"""
# Policy hyperparameters
policy_size = {policy_size}
seed = {seed}
rl_step_size = {rl_step_size}
learnrate = {learnrate}
entcoeff = {entcoeff}
batchsize = {batchsize}
num_epoch = {num_epoch}

# Value Function hyperparameters
vf_hidden_size = {vf_hidden_size}
seed = {seed}
rl_step_size = {rl_step_size}
learnrate = {learnrate}
entcoeff = {entcoeff}
batchsize = {batchsize}
num_epoch = {num_epoch}
regcoef = {regcoef}


"""

# Write data to the file
with open("myoarmreach#9/readme.txt", "w") as file: #Change the folder name 
    file.write(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 26
#       2 data = f"""
#       3 # Policy hyperparameters
#       4 policy_size = {policy_size}
#    (...)
#      22
#      23 """
#      25 # Write data to the file
# ---> 26 with open("myoarmreach#9/readme.txt", "w") as file: #Change the folder name
#      27     file.write(data)
#
# File c:\Users\Elyas\anaconda3\envs\myosuite\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myoarmreach#9/readme.txt'
