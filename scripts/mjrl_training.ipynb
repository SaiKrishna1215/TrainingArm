# %% [markdown]
# <h1> MJRL training </h1>
# MJRL Algorithms: TRPO - MBAC - PPO - NPG - DAPG <br>
# source: https://github.com/aravindr93/mjrl/tree/master/mjrl/algos

# %%
import warnings
warnings.filterwarnings('ignore')

import gym
from mjrl.utils.gym_env import GymEnv
from mjrl.policies.gaussian_mlp import MLP, RNN
from mjrl.baselines.mlp_baseline import MLPBaseline
from mjrl.algos.ppo_clip import PPO
from mjrl.algos.npg_cg import NPG
from mjrl.utils.train_agent import train_agent
import myosuite
import torch
# Out:
# MyoSuite:> Registering Myo Envs

# %% [markdown]
# <h2> Setting up GPU Usage

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Create the environment
# Find tasks in: \envs\myo\myobase or \envs\myo\myochallenge
env = gym.make('CenterReachOut-v0')
env.reset()
# Out:
#     MyoSuite: A contact-rich simulation suite for musculoskeletal motor control
#         Vittorio Caggiano, Huawei Wang, Guillaume Durandau, Massimo Sartori, Vikash Kumar
#         L4DC-2019 | https://sites.google.com/view/myosuite
# array([-2.2856e-02,  1.1130e-02, -8.2680e-02,  1.0125e-01, -4.9400e-02,
#         1.6578e-01,  1.1868e-01, -1.9320e-01, -1.9648e-01,  3.8760e-02,
#         1.6806e-01,  1.7281e-01, -2.5407e-01, -1.0998e-01,  1.4748e+00,
#         1.2882e+00,  1.0647e-01, -2.7489e-01,  3.3200e-01,  4.1140e-01,
#        -1.7716e-01, -2.6182e-01,  1.8852e-01,  1.7017e-01,  4.4773e-01,
#         2.6707e-01,  2.8278e-01, -1.0472e-02,  1.6854e-02,  7.0198e-03,
#         9.1390e-02, -6.5450e-02,  2.4350e-01,  3.3776e-01,  2.3565e-01,
#        -1.0184e-01,  6.0707e-04,  3.1420e-02, -2.0000e-01,  0.0000e+00,
#        -2.0000e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00, -9.8006e-02, -7.9256e-02,
#         1.0700e+00, -1.4108e-01, -1.6027e-01, -1.7668e-02,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00])

# %% [markdown]
# <h1> Hyperparameter tuning </h1>
# Still working on it

# %%
import numpy as np
from sklearn.model_selection import ParameterSampler

param_grid = {
    'policy_size': [(256, 256), (128, 128), (64, 64)],
    'rl_step_size': np.logspace(-4, 0, num=10),
    'learnrate': np.logspace(-4, 0, num=10),
    'entcoeff': np.logspace(-4, 0, num=10),
    'batchsize': [16, 32, 64, 128],
    'num_epoch': [5, 10, 20],
    'vf_hidden_size': [(256, 256), (128, 128), (64, 64)],
    'regcoef': np.logspace(-4, 0, num=10),
    'gamma': np.linspace(0.9, 0.999, num=10),
    'gae_lambda': np.linspace(0.9, 1.0, num=10)
}

n_iter_search = 50  

random_search = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=123))

# %%
#Policy hyperparameters
policy_size = (64, 64)  # Size of the policy network
seed = 1  # Random seed used for reproducibility
rl_step_size = 0.1
learnrate = 0.00025
entcoeff = 0.1
batchsize = 16
num_epoch = 10

#Value Function hyperparameters
vf_hidden_size = (256, 256) # Value Function Network size
seed = 1  # Random seed used for reproducibility
rl_step_size = 0.1
learnrate = 0.000325
entcoeff = 0.1
batchsize = 32
num_epoch = 10
regcoef = 1e-3

#Training hyperparameters
iterations = 1000
gamma = 0.995
gae_lambda = 0.97


# Wrap the environment
e = GymEnv(env)

# %% [markdown]
# <H1>Set Policies </h1>

# %% [markdown]
# <h2> For CenterReachOut: </h2>
#     - <b> The observation dimension </b> is: the sensory information (Time, joint Positions, Joint Velocities, Object Position, Palm Position etc... ) <br>
#     - <b> The action dimension </b> is the output of the Policy NN and represenents the 63 values of muscle actuator intensities
#
# <h2> Display Activations:</h2>
#     - When the code down below will run, it will automatically generate a tensorboard event that registers the Policy Network.

# %%
# Initialize policy and baseline
policy = MLP(e.spec, hidden_sizes=policy_size, seed=seed, init_log_std=0.25, min_log_std=1.0)
baseline = MLPBaseline(e.spec, reg_coef=regcoef, batch_size=batchsize , hidden_sizes=vf_hidden_size, epochs=num_epoch, learn_rate=learnrate)


print(e.observation_dim) #For CenterReachOut-v0: 157 
print(e.action_dim) #For CenterReachOut-v0: 63 
exit
# Initialize NPG/PPO agent
agent = NPG(e, policy, baseline, normalized_step_size=rl_step_size, seed=seed, save_logs=True,ent_coeff=entcoeff ,tensorboard_log="./ppo_objhold_tensorboard/")
# Out:
# 157
# 63

# %%
print("========================================")
print("Starting policy learning")
print("========================================")

# Train the agent
final_score = train_agent(job_name='.',
            agent=agent,
            seed=seed,
            niter=2500,
            gamma=gamma,
            gae_lambda=gae_lambda,
            sample_mode="trajectories",
            num_traj=96,
            num_samples=0,
            save_freq=50,
            evaluation_rollouts=10)

print("========================================")
print("Job Finished.")
print("========================================")
# Out:
# ========================================
# Starting policy learning
# ========================================
# ......................................................................................
# ITERATION : 0
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# Iter | Stoc Pol | Mean Pol | Best (Stoc)
#
# [ Mon Mar 31 08:40:36 2025 ]    0 -4919.05 -1800.76 -100000000.00
# ------------------  -------------
# VF_error_after          0.0448125
# VF_error_before         1.00004
# alpha                   0.0295292
# delta                   0.1
# env_samples          9600
# eval_score          -1800.76
# eval_success            0
# kl_dist                22.7823
# num_samples          9600
# rollout_success         0
# running_score       -4919.05
# rwd_dense             -49.1904
# rwd_sparse             -0.460416
# stoc_pol_max        -4395.85
# stoc_pol_mean       -4919.05
# stoc_pol_min        -5059.33
# stoc_pol_std          150.556
# success_percentage      0
# surr_improvement      nan
# time_VF                 5.02996
# time_npg                0.672461
# time_sampling          25.4897
# time_vpg                0.0405927
# ------------------  -------------
# ......................................................................................
# ITERATION : 1
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:41:07 2025 ]    1 -4888.30 -4777.80 -4919.05
# ------------------  -------------
# VF_error_after          0.0203396
# VF_error_before         0.048777
# alpha                   0.0350165
# delta                   0.1
# env_samples         19200
# eval_score          -4777.8
# eval_success            0
# kl_dist                 0.0353959
# num_samples          9600
# rollout_success         0
# running_score       -4915.97
# rwd_dense             -48.8829
# rwd_sparse             -0.461901
# stoc_pol_max        -4147.79
# stoc_pol_mean       -4888.3
# stoc_pol_min        -5060.81
# stoc_pol_std          178.051
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.05976
# time_npg                0.660059
# time_sampling          22.8178
# time_vpg                0.0368094
# ------------------  -------------
# ......................................................................................
# ITERATION : 2
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:41:38 2025 ]    2 -4913.38 -4818.46 -4888.30
# ------------------  -------------
# VF_error_after          0.0116381
# VF_error_before         0.0200639
# alpha                   0.0317078
# delta                   0.1
# env_samples         28800
# eval_score          -4818.46
# eval_success            0
# kl_dist                 0.0313997
# num_samples          9600
# rollout_success         0
# running_score       -4915.71
# rwd_dense             -49.1337
# rwd_sparse             -0.451999
# stoc_pol_max        -4243.53
# stoc_pol_mean       -4913.38
# stoc_pol_min        -5060.97
# stoc_pol_std          170.471
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.86294
# time_npg                0.600253
# time_sampling          22.3243
# time_vpg                0.0260949
# ------------------  -------------
# ......................................................................................
# ITERATION : 3
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:42:11 2025 ]    3 -4889.45 -3897.03 -4888.30
# ------------------  --------------
# VF_error_after          0.00746096
# VF_error_before         0.0127268
# alpha                   0.0365005
# delta                   0.1
# env_samples         38400
# eval_score          -3897.03
# eval_success            0
# kl_dist                 0.0374588
# num_samples          9600
# rollout_success         0
# running_score       -4913.09
# rwd_dense             -48.8945
# rwd_sparse             -0.467429
# stoc_pol_max        -4444.23
# stoc_pol_mean       -4889.45
# stoc_pol_min        -5056.04
# stoc_pol_std          149.883
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.96055
# time_npg                0.567587
# time_sampling          25.8824
# time_vpg                0.0265696
# ------------------  --------------
# ......................................................................................
# ITERATION : 4
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:42:40 2025 ]    4 -4918.61 -3822.53 -4888.30
# ------------------  --------------
# VF_error_after          0.00357161
# VF_error_before         0.00878219
# alpha                   0.0399649
# delta                   0.1
# env_samples         48000
# eval_score          -3822.53
# eval_success            0
# kl_dist                 0.0402278
# num_samples          9600
# rollout_success         0
# running_score       -4913.64
# rwd_dense             -49.1861
# rwd_sparse             -0.45832
# stoc_pol_max        -4338.83
# stoc_pol_mean       -4918.61
# stoc_pol_min        -5057.1
# stoc_pol_std          151.521
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.67839
# time_npg                0.541975
# time_sampling          21.3901
# time_vpg                0.0237932
# ------------------  --------------
# ......................................................................................
# ITERATION : 5
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:43:11 2025 ]    5 -4883.10 -4189.16 -4888.30
# ------------------  --------------
# VF_error_after          0.00108202
# VF_error_before         0.00310495
# alpha                   0.0364878
# delta                   0.1
# env_samples         57600
# eval_score          -4189.16
# eval_success            0
# kl_dist                 0.0396599
# num_samples          9600
# rollout_success         0
# running_score       -4910.58
# rwd_dense             -48.831
# rwd_sparse             -0.459125
# stoc_pol_max        -4405
# stoc_pol_mean       -4883.1
# stoc_pol_min        -5056.95
# stoc_pol_std          144.043
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.7423
# time_npg                0.546635
# time_sampling          23.0552
# time_vpg                0.025038
# ------------------  --------------
# ......................................................................................
# ITERATION : 6
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:43:40 2025 ]    6 -4926.08 -3870.85 -4883.10
# ------------------  ---------------
# VF_error_after          0.000387207
# VF_error_before         0.0013941
# alpha                   0.0307772
# delta                   0.1
# env_samples         67200
# eval_score          -3870.85
# eval_success            0
# kl_dist                 0.0345856
# num_samples          9600
# rollout_success         0
# running_score       -4912.13
# rwd_dense             -49.2608
# rwd_sparse             -0.456648
# stoc_pol_max        -4552.62
# stoc_pol_mean       -4926.08
# stoc_pol_min        -5059.2
# stoc_pol_std          132.981
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.72579
# time_npg                0.563528
# time_sampling          21.6465
# time_vpg                0.0290983
# ------------------  ---------------
# ......................................................................................
# ITERATION : 7
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:44:09 2025 ]    7 -4871.77 -3934.68 -4883.10
# ------------------  ---------------
# VF_error_after          0.000299254
# VF_error_before         0.000609772
# alpha                   0.0348724
# delta                   0.1
# env_samples         76800
# eval_score          -3934.68
# eval_success            0
# kl_dist                 0.0441069
# num_samples          9600
# rollout_success         0
# running_score       -4908.1
# rwd_dense             -48.7177
# rwd_sparse             -0.469029
# stoc_pol_max        -4300.75
# stoc_pol_mean       -4871.77
# stoc_pol_min        -5058.81
# stoc_pol_std          171.697
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.68028
# time_npg                0.537017
# time_sampling          21.4224
# time_vpg                0.0243754
# ------------------  ---------------
# ......................................................................................
# ITERATION : 8
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:44:41 2025 ]    8 -4887.11 -4578.28 -4871.77
# ------------------  ---------------
# VF_error_after          0.000143238
# VF_error_before         0.00023309
# alpha                   0.0388871
# delta                   0.1
# env_samples         86400
# eval_score          -4578.28
# eval_success            0
# kl_dist                 0.0456748
# num_samples          9600
# rollout_success         0
# running_score       -4906
# rwd_dense             -48.8711
# rwd_sparse             -0.45851
# stoc_pol_max        -4450.38
# stoc_pol_mean       -4887.11
# stoc_pol_min        -5056.61
# stoc_pol_std          139.263
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.77109
# time_npg                0.632284
# time_sampling          23.0095
# time_vpg                0.0253112
# ------------------  ---------------
# ......................................................................................
# ITERATION : 9
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:45:12 2025 ]    9 -4880.64 -4490.16 -4871.77
# ------------------  ---------------
# VF_error_after          0.000200927
# VF_error_before         0.000234472
# alpha                   0.0337124
# delta                   0.1
# env_samples         96000
# eval_score          -4490.16
# eval_success            0
# kl_dist                 0.0452108
# num_samples          9600
# rollout_success         0
# running_score       -4903.46
# rwd_dense             -48.8063
# rwd_sparse             -0.456969
# stoc_pol_max        -4353.05
# stoc_pol_mean       -4880.64
# stoc_pol_min        -5057.77
# stoc_pol_std          175.083
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.81383
# time_npg                0.519482
# time_sampling          23.0984
# time_vpg                0.0239191
# ------------------  ---------------
# ......................................................................................
# ITERATION : 10
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:45:43 2025 ]   10 -4903.61 -4371.82 -4871.77
# ------------------  ----------------
# VF_error_after           0.000143733
# VF_error_before          0.000153283
# alpha                    0.031948
# delta                    0.1
# env_samples         105600
# eval_score           -4371.82
# eval_success             0
# kl_dist                  0.0462942
# num_samples           9600
# rollout_success          0
# running_score        -4903.48
# rwd_dense              -49.0361
# rwd_sparse              -0.450709
# stoc_pol_max         -4502.61
# stoc_pol_mean        -4903.61
# stoc_pol_min         -5059.15
# stoc_pol_std           155.53
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.79222
# time_npg                 0.523869
# time_sampling           23.577
# time_vpg                 0.0255463
# ------------------  ----------------
# ......................................................................................
# ITERATION : 11
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:46:15 2025 ]   11 -4911.51 -4484.64 -4871.77
# ------------------  ----------------
# VF_error_after           0.000189724
# VF_error_before          0.000610453
# alpha                    0.0358702
# delta                    0.1
# env_samples         115200
# eval_score           -4484.64
# eval_success             0
# kl_dist                  0.0434645
# num_samples           9600
# rollout_success          0
# running_score        -4904.28
# rwd_dense              -49.1151
# rwd_sparse              -0.468455
# stoc_pol_max         -4098.94
# stoc_pol_mean        -4911.51
# stoc_pol_min         -5057.67
# stoc_pol_std           156.46
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.48815
# time_npg                 0.669163
# time_sampling           23.4649
# time_vpg                 0.0333564
# ------------------  ----------------
# ......................................................................................
# ITERATION : 12
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:46:47 2025 ]   12 -4906.13 -4423.37 -4871.77
# ------------------  ----------------
# VF_error_after           0.000191473
# VF_error_before          0.000334935
# alpha                    0.0358209
# delta                    0.1
# env_samples         124800
# eval_score           -4423.37
# eval_success             0
# kl_dist                  0.0448218
# num_samples           9600
# rollout_success          0
# running_score        -4904.47
# rwd_dense              -49.0613
# rwd_sparse              -0.451972
# stoc_pol_max         -4345.47
# stoc_pol_mean        -4906.13
# stoc_pol_min         -5057.3
# stoc_pol_std           163.855
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.2561
# time_npg                 0.517447
# time_sampling           22.5267
# time_vpg                 0.0278692
# ------------------  ----------------
# ......................................................................................
# ITERATION : 13
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:47:18 2025 ]   13 -4899.48 -4384.49 -4871.77
# ------------------  ----------------
# VF_error_after           0.000145582
# VF_error_before          0.00015371
# alpha                    0.0304414
# delta                    0.1
# env_samples         134400
# eval_score           -4384.49
# eval_success             0
# kl_dist                  0.0419922
# num_samples           9600
# rollout_success          0
# running_score        -4903.97
# rwd_dense              -48.9947
# rwd_sparse              -0.461849
# stoc_pol_max         -4450.89
# stoc_pol_mean        -4899.48
# stoc_pol_min         -5058.03
# stoc_pol_std           152.589
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.89128
# time_npg                 0.56321
# time_sampling           23.7563
# time_vpg                 0.0281014
# ------------------  ----------------
# ......................................................................................
# ITERATION : 14
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:47:48 2025 ]   14 -4882.77 -4535.12 -4871.77
# ------------------  ----------------
# VF_error_after           0.000235894
# VF_error_before          0.000915055
# alpha                    0.0346963
# delta                    0.1
# env_samples         144000
# eval_score           -4535.12
# eval_success             0
# kl_dist                  0.0422523
# num_samples           9600
# rollout_success          0
# running_score        -4901.85
# rwd_dense              -48.8277
# rwd_sparse              -0.462663
# stoc_pol_max         -4196.39
# stoc_pol_mean        -4882.77
# stoc_pol_min         -5063.03
# stoc_pol_std           168.717
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.94746
# time_npg                 0.541985
# time_sampling           21.667
# time_vpg                 0.0230715
# ------------------  ----------------
# ......................................................................................
# ITERATION : 15
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:48:21 2025 ]   15 -4891.43 -4503.25 -4871.77
# ------------------  ----------------
# VF_error_after           0.00022418
# VF_error_before          0.000246636
# alpha                    0.0328167
# delta                    0.1
# env_samples         153600
# eval_score           -4503.25
# eval_success             0
# kl_dist                  0.0474511
# num_samples           9600
# rollout_success          0
# running_score        -4900.8
# rwd_dense              -48.9142
# rwd_sparse              -0.4555
# stoc_pol_max         -4246.64
# stoc_pol_mean        -4891.43
# stoc_pol_min         -5057.79
# stoc_pol_std           187.012
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.44891
# time_npg                 0.634519
# time_sampling           24.2272
# time_vpg                 0.024107
# ------------------  ----------------
# ......................................................................................
# ITERATION : 16
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:48:52 2025 ]   16 -4888.19 -4507.71 -4871.77
# ------------------  ----------------
# VF_error_after           0.000181512
# VF_error_before          0.000228303
# alpha                    0.0424873
# delta                    0.1
# env_samples         163200
# eval_score           -4507.71
# eval_success             0
# kl_dist                  0.0451444
# num_samples           9600
# rollout_success          0
# running_score        -4899.54
# rwd_dense              -48.8819
# rwd_sparse              -0.454824
# stoc_pol_max         -4244.41
# stoc_pol_mean        -4888.19
# stoc_pol_min         -5057.46
# stoc_pol_std           176.039
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.27571
# time_npg                 0.579275
# time_sampling           22.5416
# time_vpg                 0.0274911
# ------------------  ----------------
# ......................................................................................
# ITERATION : 17
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:49:23 2025 ]   17 -4908.90 -4527.59 -4871.77
# ------------------  ----------------
# VF_error_after           0.000119984
# VF_error_before          0.000145658
# alpha                    0.0335127
# delta                    0.1
# env_samples         172800
# eval_score           -4527.59
# eval_success             0
# kl_dist                  0.041431
# num_samples           9600
# rollout_success          0
# running_score        -4900.48
# rwd_dense              -49.089
# rwd_sparse              -0.451938
# stoc_pol_max         -4453.99
# stoc_pol_mean        -4908.9
# stoc_pol_min         -5057.68
# stoc_pol_std           146.544
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.04096
# time_npg                 0.539284
# time_sampling           23.2687
# time_vpg                 0.0265689
# ------------------  ----------------
# ......................................................................................
# ITERATION : 18
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:49:53 2025 ]   18 -4854.36 -4534.24 -4871.77
# ------------------  ----------------
# VF_error_after           0.000201598
# VF_error_before          0.000243185
# alpha                    0.0365348
# delta                    0.1
# env_samples         182400
# eval_score           -4534.24
# eval_success             0
# kl_dist                  0.0463094
# num_samples           9600
# rollout_success          0
# running_score        -4895.87
# rwd_dense              -48.5436
# rwd_sparse              -0.453148
# stoc_pol_max         -4287.86
# stoc_pol_mean        -4854.36
# stoc_pol_min         -5056.31
# stoc_pol_std           186.998
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.90951
# time_npg                 0.526195
# time_sampling           22.3082
# time_vpg                 0.0254283
# ------------------  ----------------
# ......................................................................................
# ITERATION : 19
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:50:26 2025 ]   19 -4883.68 -4576.59 -4854.36
# ------------------  ----------------
# VF_error_after           0.000228185
# VF_error_before          0.000354892
# alpha                    0.0328683
# delta                    0.1
# env_samples         192000
# eval_score           -4576.59
# eval_success             0
# kl_dist                  0.0418761
# num_samples           9600
# rollout_success          0
# running_score        -4894.65
# rwd_dense              -48.8368
# rwd_sparse              -0.466235
# stoc_pol_max         -4398.1
# stoc_pol_mean        -4883.68
# stoc_pol_min         -5056.8
# stoc_pol_std           185.466
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.93447
# time_npg                 0.608673
# time_sampling           23.1706
# time_vpg                 0.0343857
# ------------------  ----------------
# ......................................................................................
# ITERATION : 20
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:50:59 2025 ]   20 -4907.56 -4572.55 -4854.36
# ------------------  ----------------
# VF_error_after           0.000124142
# VF_error_before          0.000151813
# alpha                    0.0385793
# delta                    0.1
# env_samples         201600
# eval_score           -4572.55
# eval_success             0
# kl_dist                  0.0453582
# num_samples           9600
# rollout_success          0
# running_score        -4895.94
# rwd_dense              -49.0756
# rwd_sparse              -0.460316
# stoc_pol_max         -4386.11
# stoc_pol_mean        -4907.56
# stoc_pol_min         -5060.05
# stoc_pol_std           151.905
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.65415
# time_npg                 0.626824
# time_sampling           24.1331
# time_vpg                 0.0285871
# ------------------  ----------------
# ......................................................................................
# ITERATION : 21
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:51:33 2025 ]   21 -4863.62 -4605.77 -4854.36
# ------------------  ----------------
# VF_error_after           0.000240477
# VF_error_before          0.00119969
# alpha                    0.0315339
# delta                    0.1
# env_samples         211200
# eval_score           -4605.77
# eval_success             0
# kl_dist                  0.0402886
# num_samples           9600
# rollout_success          0
# running_score        -4892.71
# rwd_dense              -48.6362
# rwd_sparse              -0.477057
# stoc_pol_max         -4115.37
# stoc_pol_mean        -4863.62
# stoc_pol_min         -5055.61
# stoc_pol_std           192.935
# success_percentage       0
# surr_improvement       nan
# time_VF                  5.3619
# time_npg                 0.687959
# time_sampling           23.828
# time_vpg                 0.0310335
# ------------------  ----------------
# ......................................................................................
# ITERATION : 22
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:52:05 2025 ]   22 -4905.50 -4521.38 -4854.36
# ------------------  ----------------
# VF_error_after           9.82327e-05
# VF_error_before          0.000130116
# alpha                    0.0361682
# delta                    0.1
# env_samples         220800
# eval_score           -4521.38
# eval_success             0
# kl_dist                  0.0447498
# num_samples           9600
# rollout_success          0
# running_score        -4893.99
# rwd_dense              -49.055
# rwd_sparse              -0.449552
# stoc_pol_max         -4496.55
# stoc_pol_mean        -4905.5
# stoc_pol_min         -5058.19
# stoc_pol_std           146.556
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.00007
# time_npg                 0.557628
# time_sampling           24.2622
# time_vpg                 0.0271282
# ------------------  ----------------
# ......................................................................................
# ITERATION : 23
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:52:36 2025 ]   23 -4861.05 -4562.78 -4854.36
# ------------------  ----------------
# VF_error_after           0.000202295
# VF_error_before          0.000280331
# alpha                    0.0338252
# delta                    0.1
# env_samples         230400
# eval_score           -4562.78
# eval_success             0
# kl_dist                  0.0485091
# num_samples           9600
# rollout_success          0
# running_score        -4890.69
# rwd_dense              -48.6105
# rwd_sparse              -0.451522
# stoc_pol_max         -4298.62
# stoc_pol_mean        -4861.05
# stoc_pol_min         -5059.69
# stoc_pol_std           198.351
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.83449
# time_npg                 0.531024
# time_sampling           23.7187
# time_vpg                 0.0275726
# ------------------  ----------------
# ......................................................................................
# ITERATION : 24
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 08:53:09 2025 ]   24 -4901.87 -4547.37 -4854.36
# ------------------  ----------------
# VF_error_after           0.000127659
# VF_error_before          0.000155603
# alpha                    0.0313431
# delta                    0.1
# env_samples         240000
# eval_score           -4547.37
# eval_success             0
# kl_dist                  0.0465728
# num_samples           9600
# rollout_success          0
# running_score        -4891.81
# rwd_dense              -49.0187
# rwd_sparse              -0.46022
# stoc_pol_max         -4446.71
# stoc_pol_mean        -4901.87
# stoc_pol_min         -5060.96
# stoc_pol_std           147.91
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.7048
# time_npg                 0.602896
# time_sampling           23.1216
# time_vpg                 0.0240314
# ------------------  ----------------
# ......................................................................................
# ITERATION : 25
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:53:48 2025 ]   25 -4933.78 -4465.89 -4854.36
# ------------------  ----------------
# VF_error_after           8.24523e-05
# VF_error_before          0.000106428
# alpha                    0.0332394
# delta                    0.1
# env_samples         249600
# eval_score           -4465.89
# eval_success             0
# kl_dist                  0.0470306
# num_samples           9600
# rollout_success          0
# running_score        -4896.01
# rwd_dense              -49.3378
# rwd_sparse              -0.450698
# stoc_pol_max         -4451.74
# stoc_pol_mean        -4933.78
# stoc_pol_min         -5056.57
# stoc_pol_std           137.151
# success_percentage       0
# surr_improvement       nan
# time_VF                  6.76731
# time_npg                 0.775022
# time_sampling           27.116
# time_vpg                 0.0336051
# ------------------  ----------------
# ......................................................................................
# ITERATION : 26
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F1B0B0>
# [ Mon Mar 31 08:54:20 2025 ]   26 -4884.59 -4554.11 -4854.36
# ------------------  ----------------
# VF_error_after           0.000164595
# VF_error_before          0.000192067
# alpha                    0.0372095
# delta                    0.1
# env_samples         259200
# eval_score           -4554.11
# eval_success             0
# kl_dist                  0.0479199
# num_samples           9600
# rollout_success          0
# running_score        -4894.87
# rwd_dense              -48.8459
# rwd_sparse              -0.454841
# stoc_pol_max         -4282.61
# stoc_pol_mean        -4884.59
# stoc_pol_min         -5055.61
# stoc_pol_std           171.766
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.3419
# time_npg                 0.567774
# time_sampling           24.3847
# time_vpg                 0.032069
# ------------------  ----------------
# ......................................................................................
# ITERATION : 27
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:54:51 2025 ]   27 -4873.60 -4614.46 -4854.36
# ------------------  ----------------
# VF_error_after           0.000192863
# VF_error_before          0.000217022
# alpha                    0.0343662
# delta                    0.1
# env_samples         268800
# eval_score           -4614.46
# eval_success             0
# kl_dist                  0.0471121
# num_samples           9600
# rollout_success          0
# running_score        -4892.74
# rwd_dense              -48.736
# rwd_sparse              -0.452687
# stoc_pol_max         -4152.26
# stoc_pol_mean        -4873.6
# stoc_pol_min         -5059.86
# stoc_pol_std           176.286
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.95722
# time_npg                 0.640235
# time_sampling           22.4677
# time_vpg                 0.0325904
# ------------------  ----------------
# ......................................................................................
# ITERATION : 28
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F1B0B0>
# [ Mon Mar 31 08:55:23 2025 ]   28 -4883.28 -4747.90 -4854.36
# ------------------  ----------------
# VF_error_after           0.000208968
# VF_error_before          0.000626024
# alpha                    0.0375672
# delta                    0.1
# env_samples         278400
# eval_score           -4747.9
# eval_success             0
# kl_dist                  0.0447566
# num_samples           9600
# rollout_success          0
# running_score        -4891.79
# rwd_dense              -48.8328
# rwd_sparse              -0.461641
# stoc_pol_max         -4359.61
# stoc_pol_mean        -4883.28
# stoc_pol_min         -5055.8
# stoc_pol_std           190.873
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.83093
# time_npg                 0.537373
# time_sampling           22.7181
# time_vpg                 0.0238457
# ------------------  ----------------
# ......................................................................................
# ITERATION : 29
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:55:55 2025 ]   29 -4886.93 -4727.71 -4854.36
# ------------------  ----------------
# VF_error_after           0.000179747
# VF_error_before          0.000223769
# alpha                    0.0324068
# delta                    0.1
# env_samples         288000
# eval_score           -4727.71
# eval_success             0
# kl_dist                  0.0432792
# num_samples           9600
# rollout_success          0
# running_score        -4891.31
# rwd_dense              -48.8693
# rwd_sparse              -0.469604
# stoc_pol_max         -4386.13
# stoc_pol_mean        -4886.93
# stoc_pol_min         -5058.57
# stoc_pol_std           167.526
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.46661
# time_npg                 0.624714
# time_sampling           23.549
# time_vpg                 0.0260942
# ------------------  ----------------
# ......................................................................................
# ITERATION : 30
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F1B0B0>
# [ Mon Mar 31 08:56:26 2025 ]   30 -4868.70 -4689.79 -4854.36
# ------------------  ----------------
# VF_error_after           0.000135923
# VF_error_before          0.00020897
# alpha                    0.0348933
# delta                    0.1
# env_samples         297600
# eval_score           -4689.79
# eval_success             0
# kl_dist                  0.0479544
# num_samples           9600
# rollout_success          0
# running_score        -4889.05
# rwd_dense              -48.6869
# rwd_sparse              -0.457396
# stoc_pol_max         -4452.96
# stoc_pol_mean        -4868.7
# stoc_pol_min         -5057.97
# stoc_pol_std           165.182
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.9908
# time_npg                 0.570204
# time_sampling           22.4699
# time_vpg                 0.0265541
# ------------------  ----------------
# ......................................................................................
# ITERATION : 31
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# Simulation couldn't be stepped as intended. Issuing a reset
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:56:57 2025 ]   31 -4824.02 -4727.92 -4854.36
# ------------------  ---------------
# VF_error_after           0.00199734
# VF_error_before          0.00218783
# alpha                    0.0335211
# delta                    0.1
# env_samples         307108
# eval_score           -4727.92
# eval_success             0
# kl_dist                  0.0476918
# num_samples           9508
# rollout_success          0
# running_score        -4882.54
# rwd_dense              -48.2402
# rwd_sparse              -0.443403
# stoc_pol_max            26.7254
# stoc_pol_mean        -4824.02
# stoc_pol_min         -5059.91
# stoc_pol_std           530.89
# success_percentage       0
# surr_improvement       nan
# time_VF                  5.57207
# time_npg                 0.709049
# time_sampling           21.6923
# time_vpg                 0.0257339
# ------------------  ---------------
# ......................................................................................
# ITERATION : 32
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F1B0B0>
# [ Mon Mar 31 08:57:30 2025 ]   32 -4875.43 -4763.72 -4824.02
# ------------------  ----------------
# VF_error_after           0.00020023
# VF_error_before          0.000460727
# alpha                    0.0386248
# delta                    0.1
# env_samples         316708
# eval_score           -4763.72
# eval_success             0
# kl_dist                  0.0482934
# num_samples           9600
# rollout_success          0
# running_score        -4881.83
# rwd_dense              -48.7543
# rwd_sparse              -0.462713
# stoc_pol_max         -4099.07
# stoc_pol_mean        -4875.43
# stoc_pol_min         -5057.08
# stoc_pol_std           193.496
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.9096
# time_npg                 0.558734
# time_sampling           25.0362
# time_vpg                 0.031112
# ------------------  ----------------
# ......................................................................................
# ITERATION : 33
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:58:00 2025 ]   33 -4883.07 -4764.11 -4824.02
# ------------------  ----------------
# VF_error_after           0.000116235
# VF_error_before          0.000143713
# alpha                    0.0322356
# delta                    0.1
# env_samples         326308
# eval_score           -4764.11
# eval_success             0
# kl_dist                  0.048656
# num_samples           9600
# rollout_success          0
# running_score        -4881.96
# rwd_dense              -48.8307
# rwd_sparse              -0.448448
# stoc_pol_max         -4445.52
# stoc_pol_mean        -4883.07
# stoc_pol_min         -5058.85
# stoc_pol_std           168.428
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.80213
# time_npg                 0.567353
# time_sampling           22.3606
# time_vpg                 0.0236158
# ------------------  ----------------
# ......................................................................................
# ITERATION : 34
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:58:33 2025 ]   34 -4873.57 -4694.31 -4824.02
# ------------------  ----------------
# VF_error_after           0.000164982
# VF_error_before          0.000197514
# alpha                    0.0428267
# delta                    0.1
# env_samples         335908
# eval_score           -4694.31
# eval_success             0
# kl_dist                  0.0425658
# num_samples           9600
# rollout_success          0
# running_score        -4881.12
# rwd_dense              -48.7357
# rwd_sparse              -0.459345
# stoc_pol_max         -4402.79
# stoc_pol_mean        -4873.57
# stoc_pol_min         -5057.13
# stoc_pol_std           164.346
# success_percentage       0
# surr_improvement       nan
# time_VF                  5.58497
# time_npg                 0.560069
# time_sampling           22.1476
# time_vpg                 0.0310736
# ------------------  ----------------
# ......................................................................................
# ITERATION : 35
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:59:06 2025 ]   35 -4833.87 -4648.35 -4824.02
# ------------------  ----------------
# VF_error_after           0.000212609
# VF_error_before          0.000258674
# alpha                    0.0315627
# delta                    0.1
# env_samples         345508
# eval_score           -4648.35
# eval_success             0
# kl_dist                  0.0490061
# num_samples           9600
# rollout_success          0
# running_score        -4876.39
# rwd_dense              -48.3387
# rwd_sparse              -0.451188
# stoc_pol_max         -4344.45
# stoc_pol_mean        -4833.87
# stoc_pol_min         -5053.59
# stoc_pol_std           192.86
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.88575
# time_npg                 0.568202
# time_sampling           24.0526
# time_vpg                 0.02631
# ------------------  ----------------
# ......................................................................................
# ITERATION : 36
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 08:59:46 2025 ]   36 -4874.84 -4681.23 -4824.02
# ------------------  ----------------
# VF_error_after           0.000193482
# VF_error_before          0.00021516
# alpha                    0.0322441
# delta                    0.1
# env_samples         355108
# eval_score           -4681.23
# eval_success             0
# kl_dist                  0.0431124
# num_samples           9600
# rollout_success          0
# running_score        -4876.24
# rwd_dense              -48.7484
# rwd_sparse              -0.447128
# stoc_pol_max         -4231.26
# stoc_pol_mean        -4874.84
# stoc_pol_min         -5055.58
# stoc_pol_std           180.711
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.4497
# time_npg                 0.743906
# time_sampling           31.5517
# time_vpg                 0.029983
# ------------------  ----------------
# ......................................................................................
# ITERATION : 37
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 09:00:18 2025 ]   37 -4822.77 -4699.65 -4824.02
# ------------------  ----------------
# VF_error_after           0.000234501
# VF_error_before          0.000287158
# alpha                    0.0324091
# delta                    0.1
# env_samples         364708
# eval_score           -4699.65
# eval_success             0
# kl_dist                  0.0429392
# num_samples           9600
# rollout_success          0
# running_score        -4870.89
# rwd_dense              -48.2277
# rwd_sparse              -0.452519
# stoc_pol_max         -4302.27
# stoc_pol_mean        -4822.77
# stoc_pol_min         -5057.94
# stoc_pol_std           200.286
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.28211
# time_npg                 0.63155
# time_sampling           23.5588
# time_vpg                 0.0345237
# ------------------  ----------------
# ......................................................................................
# ITERATION : 38
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 09:00:48 2025 ]   38 -4849.51 -4755.09 -4822.77
# ------------------  ----------------
# VF_error_after           0.000303879
# VF_error_before          0.000322301
# alpha                    0.0407915
# delta                    0.1
# env_samples         374308
# eval_score           -4755.09
# eval_success             0
# kl_dist                  0.0483274
# num_samples           9600
# rollout_success          0
# running_score        -4868.75
# rwd_dense              -48.4951
# rwd_sparse              -0.44994
# stoc_pol_max         -4246.64
# stoc_pol_mean        -4849.51
# stoc_pol_min         -5059.04
# stoc_pol_std           198.136
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.00107
# time_npg                 0.513748
# time_sampling           22.221
# time_vpg                 0.0240059
# ------------------  ----------------
# ......................................................................................
# ITERATION : 39
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 09:01:17 2025 ]   39 -4852.65 -4728.15 -4822.77
# ------------------  ----------------
# VF_error_after           0.00021852
# VF_error_before          0.000280152
# alpha                    0.0339532
# delta                    0.1
# env_samples         383908
# eval_score           -4728.15
# eval_success             0
# kl_dist                  0.0484263
# num_samples           9600
# rollout_success          0
# running_score        -4867.14
# rwd_dense              -48.5264
# rwd_sparse              -0.465235
# stoc_pol_max         -4019.41
# stoc_pol_mean        -4852.65
# stoc_pol_min         -5055.47
# stoc_pol_std           196.319
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.71865
# time_npg                 0.566913
# time_sampling           21.3211
# time_vpg                 0.0270011
# ------------------  ----------------
# ......................................................................................
# ITERATION : 40
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 09:01:46 2025 ]   40 -4840.51 -4799.25 -4822.77
# ------------------  ----------------
# VF_error_after           0.000237977
# VF_error_before          0.000309143
# alpha                    0.0361916
# delta                    0.1
# env_samples         393508
# eval_score           -4799.25
# eval_success             0
# kl_dist                  0.0447848
# num_samples           9600
# rollout_success          0
# running_score        -4864.48
# rwd_dense              -48.4051
# rwd_sparse              -0.447149
# stoc_pol_max         -4197.26
# stoc_pol_mean        -4840.51
# stoc_pol_min         -5058.45
# stoc_pol_std           200.662
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.76843
# time_npg                 0.515622
# time_sampling           21.1864
# time_vpg                 0.0265374
# ------------------  ----------------
# ......................................................................................
# ITERATION : 41
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 09:02:16 2025 ]   41 -4851.21 -4777.04 -4822.77
# ------------------  ----------------
# VF_error_after           0.000186615
# VF_error_before          0.000255506
# alpha                    0.0341452
# delta                    0.1
# env_samples         403108
# eval_score           -4777.04
# eval_success             0
# kl_dist                  0.0499344
# num_samples           9600
# rollout_success          0
# running_score        -4863.15
# rwd_dense              -48.5121
# rwd_sparse              -0.456948
# stoc_pol_max         -4223.4
# stoc_pol_mean        -4851.21
# stoc_pol_min         -5059.92
# stoc_pol_std           184.403
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.86124
# time_npg                 0.607445
# time_sampling           22.0024
# time_vpg                 0.0333662
# ------------------  ----------------
# ......................................................................................
# ITERATION : 42
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 09:02:44 2025 ]   42 -4863.97 -4739.55 -4822.77
# ------------------  ----------------
# VF_error_after           0.000146851
# VF_error_before          0.000186106
# alpha                    0.0353646
# delta                    0.1
# env_samples         412708
# eval_score           -4739.55
# eval_success             0
# kl_dist                  0.0504966
# num_samples           9600
# rollout_success          0
# running_score        -4863.23
# rwd_dense              -48.6397
# rwd_sparse              -0.457131
# stoc_pol_max         -4350.8
# stoc_pol_mean        -4863.97
# stoc_pol_min         -5057.13
# stoc_pol_std           183.781
# success_percentage       0
# surr_improvement       inf
# time_VF                  3.74995
# time_npg                 0.546488
# time_sampling           21.1056
# time_vpg                 0.0266268
# ------------------  ----------------
# ......................................................................................
# ITERATION : 43
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F80F90>
# [ Mon Mar 31 09:03:14 2025 ]   43 -4849.68 -4797.21 -4822.77
# ------------------  ----------------
# VF_error_after           0.000171791
# VF_error_before          0.000186683
# alpha                    0.0356183
# delta                    0.1
# env_samples         422308
# eval_score           -4797.21
# eval_success             0
# kl_dist                  0.0472244
# num_samples           9600
# rollout_success          0
# running_score        -4861.88
# rwd_dense              -48.4968
# rwd_sparse              -0.458074
# stoc_pol_max         -4271.98
# stoc_pol_mean        -4849.68
# stoc_pol_min         -5060.82
# stoc_pol_std           190.822
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.36118
# time_npg                 0.545401
# time_sampling           21.1829
# time_vpg                 0.0227017
# ------------------  ----------------
# ......................................................................................
# ITERATION : 44
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B2F03F90>
# [ Mon Mar 31 09:03:42 2025 ]   44 -4772.10 -4818.13 -4822.77
# ------------------  ---------------
# VF_error_after           0.00184287
# VF_error_before          0.00211271
# alpha                    0.0359369
# delta                    0.1
# env_samples         431815
# eval_score           -4818.13
# eval_success             0
# kl_dist                  0.0453123
# num_samples           9507
# rollout_success          0
# running_score        -4852.9
# rwd_dense              -47.721
# rwd_sparse              -0.448333
# stoc_pol_max            22.865
# stoc_pol_mean        -4772.1
# stoc_pol_min         -5058.26
# stoc_pol_std           537.182
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.74045
# time_npg                 0.518887
# time_sampling           21.0057
# time_vpg                 0.0230114
# ...
# surr_improvement      nan
# time_VF                 3.2341
# time_npg                0.448124
# time_sampling          20.4852
# time_vpg                0.0209997
# ------------------  --------------
# ......................................................................................
# ITERATION : 2485
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:00:13 2025 ] 2485 -209.79 -26.65 -54.98
# ------------------  ---------------
# VF_error_after          0.381069
# VF_error_before         0.85111
# alpha                   0.0401971
# delta                   0.1
# env_samples             2.23932e+07
# eval_score            -26.6504
# eval_success            0
# kl_dist                 0.0468316
# num_samples          8206
# rollout_success         0
# running_score        -205.97
# rwd_dense              -2.10309
# rwd_sparse             -0.136666
# stoc_pol_max          235.882
# stoc_pol_mean        -209.786
# stoc_pol_min        -2784.81
# stoc_pol_std          526.038
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.45874
# time_npg                0.418303
# time_sampling          18.3781
# time_vpg                0.0213699
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2486
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:00:39 2025 ] 2486 -111.74 -29.07 -54.98
# ------------------  ---------------
# VF_error_after          0.152963
# VF_error_before         0.572398
# alpha                   0.0401883
# delta                   0.1
# env_samples             2.24016e+07
# eval_score            -29.0655
# eval_success            0
# kl_dist                 0.041422
# num_samples          8425
# rollout_success         0
# running_score        -196.547
# rwd_dense              -1.12263
# rwd_sparse             -0.128755
# stoc_pol_max          355.79
# stoc_pol_mean        -111.74
# stoc_pol_min        -3280.31
# stoc_pol_std          506.401
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.06499
# time_npg                0.492758
# time_sampling          18.8387
# time_vpg                0.0215173
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2487
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:01:05 2025 ] 2487 -240.95 -0.38 -54.98
# ------------------  ---------------
# VF_error_after          0.325782
# VF_error_before         0.617122
# alpha                   0.0335654
# delta                   0.1
# env_samples             2.24102e+07
# eval_score             -0.379002
# eval_success            0
# kl_dist                 0.0416661
# num_samples          8545
# rollout_success         0
# running_score        -200.988
# rwd_dense              -2.41474
# rwd_sparse             -0.14441
# stoc_pol_max          304.037
# stoc_pol_mean        -240.951
# stoc_pol_min        -3395.79
# stoc_pol_std          625.379
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.16562
# time_npg                0.429346
# time_sampling          18.9778
# time_vpg                0.0210004
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2488
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:01:31 2025 ] 2488 -183.41  3.00 -54.98
# ------------------  ---------------
# VF_error_after          0.10041
# VF_error_before         0.490942
# alpha                   0.0419402
# delta                   0.1
# env_samples             2.24187e+07
# eval_score              2.99939
# eval_success            0
# kl_dist                 0.0495288
# num_samples          8557
# rollout_success         0
# running_score        -199.23
# rwd_dense              -1.83931
# rwd_sparse             -0.145796
# stoc_pol_max          347.65
# stoc_pol_mean        -183.408
# stoc_pol_min        -4593.76
# stoc_pol_std          665.63
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.18145
# time_npg                0.427332
# time_sampling          19.2355
# time_vpg                0.0210092
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2489
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:01:57 2025 ] 2489 -149.23  2.99 -54.98
# ------------------  ---------------
# VF_error_after          0.220712
# VF_error_before         0.737892
# alpha                   0.034873
# delta                   0.1
# env_samples             2.24273e+07
# eval_score              2.98731
# eval_success            0
# kl_dist                 0.0488491
# num_samples          8573
# rollout_success         0
# running_score        -194.23
# rwd_dense              -1.49753
# rwd_sparse             -0.13028
# stoc_pol_max          347.39
# stoc_pol_mean        -149.23
# stoc_pol_min        -3230.44
# stoc_pol_std          512.865
# success_percentage      0
# surr_improvement      inf
# time_VF                 3.15026
# time_npg                0.454334
# time_sampling          19.1955
# time_vpg                0.0210001
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2490
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:02:24 2025 ] 2490 -194.47  2.97 -54.98
# ------------------  --------------
# VF_error_after          0.212562
# VF_error_before         0.76466
# alpha                   0.0343041
# delta                   0.1
# env_samples             2.2436e+07
# eval_score              2.97136
# eval_success            0
# kl_dist                 0.0500485
# num_samples          8678
# rollout_success         0
# running_score        -194.254
# rwd_dense              -1.94994
# rwd_sparse             -0.143
# stoc_pol_max          327.989
# stoc_pol_mean        -194.471
# stoc_pol_min        -4169.78
# stoc_pol_std          650.893
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.36815
# time_npg                0.454545
# time_sampling          19.4964
# time_vpg                0.0199959
# ------------------  --------------
# ......................................................................................
# ITERATION : 2491
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:02:51 2025 ] 2491 -264.01  2.54 -54.98
# ------------------  ---------------
# VF_error_after          0.388284
# VF_error_before         0.884285
# alpha                   0.0390166
# delta                   0.1
# env_samples             2.24449e+07
# eval_score              2.54359
# eval_success            0
# kl_dist                 0.0496983
# num_samples          8906
# rollout_success         0
# running_score        -201.23
# rwd_dense              -2.64533
# rwd_sparse             -0.141536
# stoc_pol_max          193.693
# stoc_pol_mean        -264.01
# stoc_pol_min        -2628.35
# stoc_pol_std          498.831
# success_percentage      0
# surr_improvement     -inf
# time_VF                 3.32607
# time_npg                0.450623
# time_sampling          19.9627
# time_vpg                0.0220041
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2492
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:03:17 2025 ] 2492 -196.04  1.14 -54.98
# ------------------  ---------------
# VF_error_after          0.152582
# VF_error_before         0.395611
# alpha                   0.0323863
# delta                   0.1
# env_samples             2.24534e+07
# eval_score              1.1382
# eval_success            0
# kl_dist                 0.0485879
# num_samples          8560
# rollout_success         0
# running_score        -200.71
# rwd_dense              -1.96562
# rwd_sparse             -0.14058
# stoc_pol_max          339.543
# stoc_pol_mean        -196.039
# stoc_pol_min        -4037.1
# stoc_pol_std          563.987
# success_percentage      0
# surr_improvement       -2.13734e+31
# time_VF                 3.13442
# time_npg                0.438095
# time_sampling          19.2402
# time_vpg                0.0205138
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2493
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:03:43 2025 ] 2493 -212.97 -2.45 -54.98
# ------------------  ---------------
# VF_error_after          0.278439
# VF_error_before         0.729649
# alpha                   0.038985
# delta                   0.1
# env_samples             2.24619e+07
# eval_score             -2.45475
# eval_success            0
# kl_dist                 0.0471231
# num_samples          8500
# rollout_success         0
# running_score        -201.937
# rwd_dense              -2.13497
# rwd_sparse             -0.133197
# stoc_pol_max          332.088
# stoc_pol_mean        -212.974
# stoc_pol_min        -3178.98
# stoc_pol_std          521.72
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.12416
# time_npg                0.482686
# time_sampling          18.7732
# time_vpg                0.0229979
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2494
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:04:10 2025 ] 2494 -140.62 -4.43 -54.98
# ------------------  ---------------
# VF_error_after          0.256772
# VF_error_before         0.789789
# alpha                   0.0350076
# delta                   0.1
# env_samples             2.24707e+07
# eval_score             -4.43225
# eval_success            0
# kl_dist                 0.0471699
# num_samples          8752
# rollout_success         0
# running_score        -195.805
# rwd_dense              -1.41227
# rwd_sparse             -0.13555
# stoc_pol_max          237.589
# stoc_pol_mean        -140.62
# stoc_pol_min        -2525.85
# stoc_pol_std          431.35
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.24353
# time_npg                0.470705
# time_sampling          19.4618
# time_vpg                0.0235157
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2495
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:04:36 2025 ] 2495 -81.37 -28.21 -54.98
# ------------------  ---------------
# VF_error_after          0.461133
# VF_error_before         1.38136
# alpha                   0.0321595
# delta                   0.1
# env_samples             2.24792e+07
# eval_score            -28.2108
# eval_success            0
# kl_dist                 0.0463175
# num_samples          8546
# rollout_success         0
# running_score        -184.362
# rwd_dense              -0.819383
# rwd_sparse             -0.132253
# stoc_pol_max          270.254
# stoc_pol_mean         -81.3734
# stoc_pol_min        -1677.92
# stoc_pol_std          306.587
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.25457
# time_npg                0.439309
# time_sampling          19.0306
# time_vpg                0.0210009
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2496
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:05:01 2025 ] 2496 -178.30 -0.81 -54.98
# ------------------  ---------------
# VF_error_after          0.0994027
# VF_error_before         0.90234
# alpha                   0.0329327
# delta                   0.1
# env_samples             2.24875e+07
# eval_score             -0.813077
# eval_success            0
# kl_dist                 0.0475604
# num_samples          8236
# rollout_success         0
# running_score        -183.756
# rwd_dense              -1.78865
# rwd_sparse             -0.137166
# stoc_pol_max          285.826
# stoc_pol_mean        -178.3
# stoc_pol_min        -4058.28
# stoc_pol_std          608.267
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.02397
# time_npg                0.428252
# time_sampling          18.3581
# time_vpg                0.0210009
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2497
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:05:28 2025 ] 2497 -278.79  1.60 -54.98
# ------------------  ---------------
# VF_error_after          0.175901
# VF_error_before         0.466942
# alpha                   0.0376918
# delta                   0.1
# env_samples             2.24961e+07
# eval_score              1.60164
# eval_success            0
# kl_dist                 0.0480928
# num_samples          8610
# rollout_success         0
# running_score        -193.259
# rwd_dense              -2.79393
# rwd_sparse             -0.156384
# stoc_pol_max          384.559
# stoc_pol_mean        -278.786
# stoc_pol_min        -4507.99
# stoc_pol_std          821.087
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.13891
# time_npg                0.45795
# time_sampling          19.474
# time_vpg                0.0245156
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2498
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:05:54 2025 ] 2498 -168.23 -28.46 -54.98
# ------------------  ---------------
# VF_error_after          0.427137
# VF_error_before         0.717622
# alpha                   0.0336776
# delta                   0.1
# env_samples             2.25048e+07
# eval_score            -28.4577
# eval_success            0
# kl_dist                 0.0472223
# num_samples          8702
# rollout_success         0
# running_score        -190.756
# rwd_dense              -1.6875
# rwd_sparse             -0.136541
# stoc_pol_max          284.962
# stoc_pol_mean        -168.227
# stoc_pol_min        -3260.16
# stoc_pol_std          534.574
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.16026
# time_npg                0.485582
# time_sampling          19.2944
# time_vpg                0.0262039
# ------------------  ---------------
# ......................................................................................
# ITERATION : 2499
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x00000244B0471CF0>
# [ Tue Apr  1 04:06:22 2025 ] 2499 -119.32 -30.20 -54.98
# ------------------  ---------------
# VF_error_after          0.0860084
# VF_error_before         0.446407
# alpha                   0.0331047
# delta                   0.1
# env_samples             2.25138e+07
# eval_score            -30.201
# eval_success            0
# kl_dist                 0.0483763
# num_samples          9004
# rollout_success         0
# running_score        -183.612
# rwd_dense              -1.19841
# rwd_sparse             -0.143581
# stoc_pol_max          242.079
# stoc_pol_mean        -119.318
# stoc_pol_min        -4532.25
# stoc_pol_std          541.637
# success_percentage      0
# surr_improvement      nan
# time_VF                 3.36351
# time_npg                0.482407
# time_sampling          20.2731
# time_vpg                0.0215118
# ------------------  ---------------
# ========================================
# Job Finished.
# ========================================

# %% [markdown]
# <h1> Logging hyperparameters

# %%
import logging

# Configure the logging system
logging.basicConfig(
    filename=r'C:\Users\Elyas\OneDrive - The University of Colorado Denver\Desktop\Research 2024\Research_papers/training_hyperparameters.log',  # Log file name
    level=logging.INFO,  # Set the logging level to INFO
    format='%(asctime)s - %(levelname)s - %(message)s',  # Log message format
)

# %%
# Policy Network Hyperparameters
policy_hyperparameters = {
    'policy_size': (256, 256),
    'seed': 123,
    'rl_step_size': 0.1,
    'learnrate': 0.0025,
    'entcoeff': 0.1,
    'batchsize': 32,
    'num_epoch': 10,
}

# Value Function Network Hyperparameters
vf_hyperparameters = {
    'vf_hidden_size': (256, 256),
    'seed': 123,
    'rl_step_size': 0.1,
    'learnrate': 0.000325,
    'entcoeff': 0.1,
    'batchsize': 32,
    'num_epoch': 10,
    'regcoef': 1e-3,
}

# Training Hyperparameters
training_hyperparameters = {
    'iterations': 1000,
    'gamma': 0.995,
    'gae_lambda': 0.97,
}

# Log Hyperparameters
def log_hyperparameters():
    logging.info("Policy Network Hyperparameters:")
    for key, value in policy_hyperparameters.items():
        logging.info(f"{key}: {value}")
    
    logging.info("\nValue Function Network Hyperparameters:")
    for key, value in vf_hyperparameters.items():
        logging.info(f"{key}: {value}")
    
    logging.info("\nTraining Hyperparameters:")
    for key, value in training_hyperparameters.items():
        logging.info(f"{key}: {value}")

# Call the function to log hyperparameters
log_hyperparameters()
