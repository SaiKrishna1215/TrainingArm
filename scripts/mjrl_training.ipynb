# %% [markdown]
# <h1> MJRL training </h1>
# MJRL Algorithms: TRPO - MBAC - PPO - NPG - DAPG <br>
# source: https://github.com/aravindr93/mjrl/tree/master/mjrl/algos

# %%
import warnings
warnings.filterwarnings('ignore')

import gym
from mjrl.utils.gym_env import GymEnv
from mjrl.policies.gaussian_mlp import MLP, RNN, LSTM
from mjrl.baselines.mlp_baseline import MLPBaseline
from mjrl.algos.ppo_clip import PPO
from mjrl.algos.npg_cg import NPG
from mjrl.utils.train_agent import train_agent
import myosuite
import torch
# Out:
# MyoSuite:> Registering Myo Envs

# %% [markdown]
# <h2> Setting up GPU Usage

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Create the environment
# Find tasks in: \envs\myo\myobase or \envs\myo\myochallenge
env = gym.make('CenterReachOut-v0')
env.reset()
# Out:
#     MyoSuite: A contact-rich simulation suite for musculoskeletal motor control
#         Vittorio Caggiano, Huawei Wang, Guillaume Durandau, Massimo Sartori, Vikash Kumar
#         L4DC-2019 | https://sites.google.com/view/myosuite
# array([-2.2856e-02,  1.1130e-02, -8.2680e-02,  1.0125e-01, -4.9400e-02,
#         1.6578e-01,  1.1868e-01, -1.9320e-01, -1.9648e-01,  3.8760e-02,
#         1.6806e-01,  1.7281e-01, -2.5407e-01, -1.0998e-01,  1.4748e+00,
#         1.2882e+00,  1.0647e-01, -2.7489e-01,  3.3200e-01,  4.1140e-01,
#        -1.7716e-01, -2.6182e-01,  1.8852e-01,  1.7017e-01,  4.4773e-01,
#         2.6707e-01,  2.8278e-01, -1.0472e-02,  1.6854e-02,  7.0198e-03,
#         9.1390e-02, -6.5450e-02,  2.4350e-01,  3.3776e-01,  2.3565e-01,
#        -1.0184e-01,  6.0707e-04,  3.1420e-02, -2.0000e-01,  0.0000e+00,
#        -2.0000e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00, -4.1969e-01, -2.1250e-01,
#         1.0700e+00,  1.8060e-01, -2.7030e-02, -1.7668e-02,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00])

# %% [markdown]
# <h1> Hyperparameter tuning </h1>
# Still working on it

# %%
import numpy as np
from sklearn.model_selection import ParameterSampler

param_grid = {
    'policy_size': [(256, 256), (128, 128), (64, 64)],
    'rl_step_size': np.logspace(-4, 0, num=10),
    'learnrate': np.logspace(-4, 0, num=10),
    'entcoeff': np.logspace(-4, 0, num=10),
    'batchsize': [16, 32, 64, 128],
    'num_epoch': [5, 10, 20],
    'vf_hidden_size': [(256, 256), (128, 128), (64, 64)],
    'regcoef': np.logspace(-4, 0, num=10),
    'gamma': np.linspace(0.9, 0.999, num=10),
    'gae_lambda': np.linspace(0.9, 1.0, num=10)
}

n_iter_search = 50  

random_search = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=123))

# %%
#Policy hyperparameters
policy_size = (64, 64)  # Size of the policy network
seed = 1  # Random seed used for reproducibility
rl_step_size = 0.1
learnrate = 0.00025
entcoeff = 0.1
batchsize = 16
num_epoch = 10

#Value Function hyperparameters
vf_hidden_size = (256, 256) # Value Function Network size
seed = 1  # Random seed used for reproducibility
rl_step_size = 0.1
learnrate = 0.000325
entcoeff = 0.1
batchsize = 32
num_epoch = 10
regcoef = 1e-3

#Training hyperparameters
iterations = 1000
gamma = 0.995
gae_lambda = 0.97


# Wrap the environment
e = GymEnv(env)

# %% [markdown]
# <H1>Set Policies </h1>

# %% [markdown]
# <h2> For CenterReachOut: </h2>
#     - <b> The observation dimension </b> is: the sensory information (Time, joint Positions, Joint Velocities, Object Position, Palm Position etc... ) <br>
#     - <b> The action dimension </b> is the output of the Policy NN and represenents the 63 values of muscle actuator intensities
#
# <h2> Display Activations:</h2>
#     - When the code down below will run, it will automatically generate a tensorboard event that registers the Policy Network.

# %%
# Initialize policy and baseline
# policy = MLP(e.spec, hidden_sizes=policy_size, seed=seed, init_log_std=0.25, min_log_std=1.0)

policy = LSTM(
    env_spec=e.spec,
    hidden_sizes=policy_size,          
    lstm_hidden_size=64,              
    mlp_hidden_size=64,  
    init_log_std=0.25,
    min_log_std=1.0,
    seed=seed
)



baseline = MLPBaseline(e.spec, reg_coef=regcoef, batch_size=batchsize , hidden_sizes=vf_hidden_size, epochs=num_epoch, learn_rate=learnrate)


print(e.observation_dim) #For CenterReachOut-v0: 157 
print(e.action_dim) #For CenterReachOut-v0: 63 
exit
# Initialize NPG/PPO agent
agent = NPG(e, policy, baseline, normalized_step_size=rl_step_size, seed=seed, save_logs=True,ent_coeff=entcoeff ,tensorboard_log="./ppo_objhold_tensorboard/")
# Out:
# 157
# 63

# %%
print("========================================")
print("Starting policy learning")
print("========================================")

# Train the agent
final_score = train_agent(job_name='.',
            agent=agent,
            seed=seed,
            niter=1850,
            gamma=gamma,
            gae_lambda=gae_lambda,
            sample_mode="trajectories",
            num_traj=96,
            num_samples=0,
            save_freq=50,
            evaluation_rollouts=10)

print("========================================")
print("Job Finished.")
print("========================================")
# Out:
# ========================================
# Starting policy learning
# ========================================
# ......................................................................................
# ITERATION : 0
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# Iter | Stoc Pol | Mean Pol | Best (Stoc)
#
# [ Wed May 14 06:41:44 2025 ]    0 -4871.58 -1519.05 -100000000.00
# ------------------  ---------------
# VF_error_after          0.0421586
# VF_error_before         0.999975
# alpha                   0.700176
# delta                   0.1
# env_samples          9600
# eval_score          -1519.05
# eval_success            0
# kl_dist                22.7894
# num_samples          9600
# rollout_success         0
# running_score       -4871.58
# rwd_dense             -48.7157
# rwd_sparse             -0.457814
# stoc_pol_max        -4247.33
# stoc_pol_mean       -4871.58
# stoc_pol_min        -5050.99
# stoc_pol_std          182.497
# success_percentage      0
# surr_improvement       -1.08446e-05
# time_VF                 3.74478
# time_npg                1.66646
# time_sampling          16.1857
# time_vpg                0.0781345
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:42:08 2025 ]    1 -4868.73 -3698.34 -4871.58
# ------------------  -------------
# VF_error_after          0.0193196
# VF_error_before         0.0553735
# alpha                   0.959772
# delta                   0.1
# env_samples         19200
# eval_score          -3698.34
# eval_success            0
# kl_dist                 0.135773
# num_samples          9600
# rollout_success         0
# running_score       -4871.29
# rwd_dense             -48.6873
# rwd_sparse             -0.463539
# stoc_pol_max        -4022.88
# stoc_pol_mean       -4868.73
# stoc_pol_min        -5048.49
# stoc_pol_std          188.202
# success_percentage      0
# surr_improvement        0.0800679
# time_VF                 3.97033
# time_npg                1.63636
# time_sampling          16.1136
# time_vpg                0.0492601
# ------------------  -------------
# ......................................................................................
# ITERATION : 2
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:42:32 2025 ]    2 -4881.00 -4510.01 -4868.73
# ------------------  --------------
# VF_error_after          0.00779635
# VF_error_before         0.0173662
# alpha                   0.903794
# delta                   0.1
# env_samples         28800
# eval_score          -4510.01
# eval_success            0
# kl_dist                 0.088487
# num_samples          9600
# rollout_success         0
# running_score       -4872.26
# rwd_dense             -48.8101
# rwd_sparse             -0.432342
# stoc_pol_max        -4279.69
# stoc_pol_mean       -4881
# stoc_pol_min        -5049.91
# stoc_pol_std          171.112
# success_percentage      0
# surr_improvement        0.137468
# time_VF                 4.03414
# time_npg                1.63939
# time_sampling          15.9683
# time_vpg                0.0453005
# ------------------  --------------
# ......................................................................................
# ITERATION : 3
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:42:57 2025 ]    3 -4878.37 -4136.07 -4868.73
# ------------------  --------------
# VF_error_after          0.00552644
# VF_error_before         0.00864952
# alpha                   1.14234
# delta                   0.1
# env_samples         38400
# eval_score          -4136.07
# eval_success            0
# kl_dist                 0.0500119
# num_samples          9600
# rollout_success         0
# running_score       -4872.87
# rwd_dense             -48.7837
# rwd_sparse             -0.433299
# stoc_pol_max        -4431.45
# stoc_pol_mean       -4878.37
# stoc_pol_min        -5048.87
# stoc_pol_std          151.47
# success_percentage      0
# surr_improvement        0.086637
# time_VF                 3.97917
# time_npg                1.6246
# time_sampling          16.1887
# time_vpg                0.0512874
# ------------------  --------------
# ......................................................................................
# ITERATION : 4
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:43:21 2025 ]    4 -4838.53 -4175.42 -4868.73
# ------------------  --------------
# VF_error_after          0.00484802
# VF_error_before         0.00749688
# alpha                   1.0118
# delta                   0.1
# env_samples         47905
# eval_score          -4175.42
# eval_success            0
# kl_dist                 0.0607712
# num_samples          9505
# rollout_success         0
# running_score       -4869.44
# rwd_dense             -48.3853
# rwd_sparse             -0.435666
# stoc_pol_max           15.5518
# stoc_pol_mean       -4838.53
# stoc_pol_min        -5049.78
# stoc_pol_std          524.446
# success_percentage      0
# surr_improvement        0.174181
# time_VF                 3.98322
# time_npg                1.61447
# time_sampling          15.9437
# time_vpg                0.0475481
# ------------------  --------------
# ......................................................................................
# ITERATION : 5
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:43:45 2025 ]    5 -4862.38 -3314.68 -4838.53
# ------------------  -------------
# VF_error_after          0.0015148
# VF_error_before         0.0038553
# alpha                   1.0864
# delta                   0.1
# env_samples         57505
# eval_score          -3314.68
# eval_success            0
# kl_dist                 0.0476208
# num_samples          9600
# rollout_success         0
# running_score       -4868.73
# rwd_dense             -48.6238
# rwd_sparse             -0.436338
# stoc_pol_max        -4437.04
# stoc_pol_mean       -4862.38
# stoc_pol_min        -5047.44
# stoc_pol_std          150.729
# success_percentage      0
# surr_improvement        0.0883309
# time_VF                 3.98279
# time_npg                1.61513
# time_sampling          16.0078
# time_vpg                0.0484703
# ------------------  -------------
# ......................................................................................
# ITERATION : 6
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:44:09 2025 ]    6 -4879.21 -4465.81 -4838.53
# ------------------  ---------------
# VF_error_after          0.000689342
# VF_error_before         0.00200341
# alpha                   1.17525
# delta                   0.1
# env_samples         67105
# eval_score          -4465.81
# eval_success            0
# kl_dist                 0.0505694
# num_samples          9600
# rollout_success         0
# running_score       -4869.78
# rwd_dense             -48.7921
# rwd_sparse             -0.422696
# stoc_pol_max        -4290.36
# stoc_pol_mean       -4879.21
# stoc_pol_min        -5048.28
# stoc_pol_std          162.956
# success_percentage      0
# surr_improvement        0.0835008
# time_VF                 3.96236
# time_npg                1.66362
# time_sampling          16.0941
# time_vpg                0.0411801
# ------------------  ---------------
# ......................................................................................
# ITERATION : 7
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:44:34 2025 ]    7 -4819.16 -4043.70 -4838.53
# ------------------  ---------------
# VF_error_after          0.00055688
# VF_error_before         0.000893655
# alpha                   1.00424
# delta                   0.1
# env_samples         76705
# eval_score          -4043.7
# eval_success            0
# kl_dist                 0.0558139
# num_samples          9600
# rollout_success         0
# running_score       -4864.72
# rwd_dense             -48.1915
# rwd_sparse             -0.425708
# stoc_pol_max        -4288.69
# stoc_pol_mean       -4819.16
# stoc_pol_min        -5046.39
# stoc_pol_std          192.878
# success_percentage      0
# surr_improvement        0.11993
# time_VF                 3.96477
# time_npg                1.62758
# time_sampling          16.1379
# time_vpg                0.0574627
# ------------------  ---------------
# ......................................................................................
# ITERATION : 8
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:44:58 2025 ]    8 -4801.40 -3915.46 -4819.16
# ------------------  ---------------
# VF_error_after          0.000502323
# VF_error_before         0.000810988
# alpha                   1.01178
# delta                   0.1
# env_samples         86305
# eval_score          -3915.46
# eval_success            0
# kl_dist                 0.0533175
# num_samples          9600
# rollout_success         0
# running_score       -4858.39
# rwd_dense             -48.014
# rwd_sparse             -0.431532
# stoc_pol_max        -4241.04
# stoc_pol_mean       -4801.4
# stoc_pol_min        -5047.9
# stoc_pol_std          208.218
# success_percentage      0
# surr_improvement        0.13431
# time_VF                 3.88365
# time_npg                1.63925
# time_sampling          16.1136
# time_vpg                0.0488167
# ------------------  ---------------
# ......................................................................................
# ITERATION : 9
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:45:22 2025 ]    9 -4764.50 -3991.16 -4801.40
# ------------------  ---------------
# VF_error_after          0.000804769
# VF_error_before         0.0011725
# alpha                   0.971555
# delta                   0.1
# env_samples         95905
# eval_score          -3991.16
# eval_success            0
# kl_dist                 0.0531976
# num_samples          9600
# rollout_success         0
# running_score       -4849
# rwd_dense             -47.6451
# rwd_sparse             -0.431513
# stoc_pol_max        -4010.94
# stoc_pol_mean       -4764.5
# stoc_pol_min        -5049.3
# stoc_pol_std          278.587
# success_percentage      0
# surr_improvement        0.188797
# time_VF                 3.9341
# time_npg                1.63932
# time_sampling          16.0647
# time_vpg                0.0483925
# ------------------  ---------------
# ......................................................................................
# ITERATION : 10
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:45:47 2025 ]   10 -4689.17 -3852.42 -4764.50
# ------------------  ---------------
# VF_error_after           0.0014443
# VF_error_before          0.00199924
# alpha                    0.930725
# delta                    0.1
# env_samples         105505
# eval_score           -3852.42
# eval_success             0
# kl_dist                  0.049891
# num_samples           9600
# rollout_success          0
# running_score        -4833.02
# rwd_dense              -46.8917
# rwd_sparse              -0.41295
# stoc_pol_max         -3683.89
# stoc_pol_mean        -4689.17
# stoc_pol_min         -5050.08
# stoc_pol_std           334.031
# success_percentage       0
# surr_improvement         0.131247
# time_VF                  4.12544
# time_npg                 1.69042
# time_sampling           16.4661
# time_vpg                 0.0502985
# ------------------  ---------------
# ......................................................................................
# ITERATION : 11
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:46:13 2025 ]   11 -4583.63 -3830.72 -4689.17
# ------------------  ---------------
# VF_error_after           0.00242148
# VF_error_before          0.0028441
# alpha                    0.939905
# delta                    0.1
# env_samples         115010
# eval_score           -3830.72
# eval_success             0
# kl_dist                  0.0507082
# num_samples           9505
# rollout_success          0
# running_score        -4808.08
# rwd_dense              -45.8424
# rwd_sparse              -0.417099
# stoc_pol_max            15.5366
# stoc_pol_mean        -4583.63
# stoc_pol_min         -5049.92
# stoc_pol_std           587.698
# success_percentage       0
# surr_improvement         0.459034
# time_VF                  4.27034
# time_npg                 1.71188
# time_sampling           17.1478
# time_vpg                 0.0488842
# ------------------  ---------------
# ......................................................................................
# ITERATION : 12
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:46:39 2025 ]   12 -4556.49 -2447.07 -4583.63
# ------------------  ---------------
# VF_error_after           0.0018087
# VF_error_before          0.00258523
# alpha                    0.70812
# delta                    0.1
# env_samples         124610
# eval_score           -2447.07
# eval_success             0
# kl_dist                  0.0539928
# num_samples           9600
# rollout_success          0
# running_score        -4782.92
# rwd_dense              -45.565
# rwd_sparse              -0.454749
# stoc_pol_max         -3473.99
# stoc_pol_mean        -4556.49
# stoc_pol_min         -5046.56
# stoc_pol_std           437.134
# success_percentage       0
# surr_improvement         0.262279
# time_VF                  4.43446
# time_npg                 1.75417
# time_sampling           17.3157
# time_vpg                 0.0519404
# ------------------  ---------------
# ......................................................................................
# ITERATION : 13
# Simulation couldn't be stepped as intended. Issuing a reset
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:47:04 2025 ]   13 -4457.87 -2559.36 -4556.49
# ------------------  ---------------
# VF_error_after           0.00261539
# VF_error_before          0.00292497
# alpha                    0.80005
# delta                    0.1
# env_samples         134210
# eval_score           -2559.36
# eval_success             0
# kl_dist                  0.0502326
# num_samples           9600
# rollout_success          0
# running_score        -4750.41
# rwd_dense              -44.5787
# rwd_sparse              -0.435553
# stoc_pol_max         -3389.34
# stoc_pol_mean        -4457.87
# stoc_pol_min         -5049.54
# stoc_pol_std           440.92
# success_percentage       0
# surr_improvement         0.166676
# time_VF                  3.93421
# time_npg                 1.62796
# time_sampling           16.4039
# time_vpg                 0.050339
# ------------------  ---------------
# ......................................................................................
# ITERATION : 14
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:47:29 2025 ]   14 -4334.82 -2234.43 -4457.87
# ------------------  ---------------
# VF_error_after           0.00311408
# VF_error_before          0.00375844
# alpha                    0.757073
# delta                    0.1
# env_samples         143810
# eval_score           -2234.43
# eval_success             0
# kl_dist                  0.0536423
# num_samples           9600
# rollout_success          0
# running_score        -4708.85
# rwd_dense              -43.3482
# rwd_sparse              -0.442183
# stoc_pol_max         -3241.61
# stoc_pol_mean        -4334.82
# stoc_pol_min         -5045.8
# stoc_pol_std           476.352
# success_percentage       0
# surr_improvement         0.204755
# time_VF                  4.04338
# time_npg                 1.62324
# time_sampling           16.3568
# time_vpg                 0.0521395
# ------------------  ---------------
# ......................................................................................
# ITERATION : 15
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:47:53 2025 ]   15 -4234.00 -2267.39 -4334.82
# ------------------  ---------------
# VF_error_after           0.00543772
# VF_error_before          0.00717573
# alpha                    0.745092
# delta                    0.1
# env_samples         153410
# eval_score           -2267.39
# eval_success             0
# kl_dist                  0.0551426
# num_samples           9600
# rollout_success          0
# running_score        -4661.37
# rwd_dense              -42.34
# rwd_sparse              -0.395185
# stoc_pol_max         -2586.39
# stoc_pol_mean        -4234
# stoc_pol_min         -5044.64
# stoc_pol_std           554.491
# success_percentage       0
# surr_improvement         0.257954
# time_VF                  4.02104
# time_npg                 1.64106
# time_sampling           16.2201
# time_vpg                 0.0511172
# ------------------  ---------------
# ......................................................................................
# ITERATION : 16
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:48:18 2025 ]   16 -4133.82 -2122.16 -4234.00
# ------------------  ---------------
# VF_error_after           0.00700677
# VF_error_before          0.00928601
# alpha                    0.729514
# delta                    0.1
# env_samples         163010
# eval_score           -2122.16
# eval_success             0
# kl_dist                  0.0508342
# num_samples           9600
# rollout_success          0
# running_score        -4608.61
# rwd_dense              -41.3383
# rwd_sparse              -0.409501
# stoc_pol_max         -2603.12
# stoc_pol_mean        -4133.82
# stoc_pol_min         -5044.28
# stoc_pol_std           644.142
# success_percentage       0
# surr_improvement         0.179364
# time_VF                  3.94619
# time_npg                 1.61962
# time_sampling           16.3198
# time_vpg                 0.0484791
# ------------------  ---------------
# ......................................................................................
# ITERATION : 17
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:48:42 2025 ]   17 -3917.57 -2045.87 -4133.82
# ------------------  --------------
# VF_error_after           0.0137374
# VF_error_before          0.0198603
# alpha                    0.555703
# delta                    0.1
# env_samples         172536
# eval_score           -2045.87
# eval_success             0
# kl_dist                  0.0444727
# num_samples           9526
# rollout_success          0
# running_score        -4539.51
# rwd_dense              -39.1756
# rwd_sparse              -0.380951
# stoc_pol_max            94.0263
# stoc_pol_mean        -3917.57
# stoc_pol_min         -5102.51
# stoc_pol_std           831.054
# success_percentage       0
# surr_improvement         0.26379
# time_VF                  3.87613
# time_npg                 1.60675
# time_sampling           16.1861
# time_vpg                 0.0569186
# ------------------  --------------
# ......................................................................................
# ITERATION : 18
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:49:07 2025 ]   18 -3738.37 -2182.31 -3917.57
# ------------------  --------------
# VF_error_after           0.0149015
# VF_error_before          0.0211159
# alpha                    0.65847
# delta                    0.1
# env_samples         182136
# eval_score           -2182.31
# eval_success             0
# kl_dist                  0.0507141
# num_samples           9600
# rollout_success          0
# running_score        -4459.4
# rwd_dense              -37.3837
# rwd_sparse              -0.362826
# stoc_pol_max         -1672.68
# stoc_pol_mean        -3738.37
# stoc_pol_min         -5046.08
# stoc_pol_std           859.401
# success_percentage       0
# surr_improvement         0.164035
# time_VF                  3.96438
# time_npg                 1.62999
# time_sampling           16.2469
# time_vpg                 0.0484722
# ------------------  --------------
# ......................................................................................
# ITERATION : 19
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:49:32 2025 ]   19 -3826.23 -2086.85 -3738.37
# ------------------  ---------------
# VF_error_after           0.00912308
# VF_error_before          0.0108273
# alpha                    0.816608
# delta                    0.1
# env_samples         191736
# eval_score           -2086.85
# eval_success             0
# kl_dist                  0.046776
# num_samples           9600
# rollout_success          0
# running_score        -4396.08
# rwd_dense              -38.2623
# rwd_sparse              -0.353142
# stoc_pol_max         -2080.54
# stoc_pol_mean        -3826.23
# stoc_pol_min         -5045.18
# stoc_pol_std           800.299
# success_percentage       0
# surr_improvement         0.136989
# time_VF                  4.12851
# time_npg                 1.63914
# time_sampling           16.3785
# time_vpg                 0.0426874
# ------------------  ---------------
# ......................................................................................
# ITERATION : 20
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:49:56 2025 ]   20 -3740.10 -2025.74 -3738.37
# ------------------  --------------
# VF_error_after           0.0137041
# VF_error_before          0.0165643
# alpha                    0.744711
# delta                    0.1
# env_samples         201314
# eval_score           -2025.74
# eval_success             0
# kl_dist                  0.0484623
# num_samples           9578
# rollout_success          0
# running_score        -4330.48
# rwd_dense              -37.401
# rwd_sparse              -0.365525
# stoc_pol_max         -2091.77
# stoc_pol_mean        -3740.1
# stoc_pol_min         -5044.53
# stoc_pol_std           807.388
# success_percentage       0
# surr_improvement         0.123135
# time_VF                  3.99234
# time_npg                 1.62922
# time_sampling           16.4169
# time_vpg                 0.058809
# ------------------  --------------
# ......................................................................................
# ITERATION : 21
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:50:21 2025 ]   21 -3719.49 -2074.20 -3738.37
# ------------------  --------------
# VF_error_after           0.0218567
# VF_error_before          0.024994
# alpha                    0.85759
# delta                    0.1
# env_samples         210857
# eval_score           -2074.2
# eval_success             0
# kl_dist                  0.0462758
# num_samples           9543
# rollout_success          0
# running_score        -4269.38
# rwd_dense              -37.1949
# rwd_sparse              -0.35038
# stoc_pol_max            25.9499
# stoc_pol_mean        -3719.49
# stoc_pol_min         -5036.28
# stoc_pol_std           885.811
# success_percentage       0
# surr_improvement         0.12641
# time_VF                  4.06417
# time_npg                 1.62582
# time_sampling           16.2616
# time_vpg                 0.0488296
# ------------------  --------------
# ......................................................................................
# ITERATION : 22
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:50:46 2025 ]   22 -3825.11 -2750.04 -3719.49
# ------------------  --------------
# VF_error_after           0.014562
# VF_error_before          0.0166465
# alpha                    0.945538
# delta                    0.1
# env_samples         220436
# eval_score           -2750.04
# eval_success             0
# kl_dist                  0.0494696
# num_samples           9579
# rollout_success          0
# running_score        -4224.96
# rwd_dense              -38.2509
# rwd_sparse              -0.359719
# stoc_pol_max         -1318.29
# stoc_pol_mean        -3825.11
# stoc_pol_min         -5040.22
# stoc_pol_std           827.723
# success_percentage       0
# surr_improvement         0.100273
# time_VF                  4.13837
# time_npg                 1.64253
# time_sampling           16.5005
# time_vpg                 0.055203
# ------------------  --------------
# ......................................................................................
# ITERATION : 23
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:51:10 2025 ]   23 -3637.49 -1824.01 -3719.49
# ------------------  --------------
# VF_error_after           0.0285985
# VF_error_before          0.036175
# alpha                    0.909422
# delta                    0.1
# env_samples         229901
# eval_score           -1824.01
# eval_success             0
# kl_dist                  0.0489222
# num_samples           9465
# rollout_success          0
# running_score        -4166.21
# rwd_dense              -36.3749
# rwd_sparse              -0.354131
# stoc_pol_max            48.9183
# stoc_pol_mean        -3637.49
# stoc_pol_min         -5045.97
# stoc_pol_std          1036.86
# success_percentage       0
# surr_improvement         0.138683
# time_VF                  4.12806
# time_npg                 1.59122
# time_sampling           16.2726
# time_vpg                 0.0605042
# ------------------  --------------
# ......................................................................................
# ITERATION : 24
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:51:35 2025 ]   24 -3276.97 -1108.73 -3637.49
# ------------------  --------------
# VF_error_after           0.0485706
# VF_error_before          0.0568393
# alpha                    0.859686
# delta                    0.1
# env_samples         239390
# eval_score           -1108.73
# eval_success             0
# kl_dist                  0.0493176
# num_samples           9489
# rollout_success          0
# running_score        -4077.28
# rwd_dense              -32.7697
# rwd_sparse              -0.336231
# stoc_pol_max            82.7553
# stoc_pol_mean        -3276.97
# stoc_pol_min         -5033.71
# stoc_pol_std          1120.6
# success_percentage       0
# surr_improvement         0.113214
# time_VF                  4.07131
# time_npg                 1.60699
# time_sampling           16.1015
# time_vpg                 0.0568435
# ------------------  --------------
# ......................................................................................
# ITERATION : 25
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:52:00 2025 ]   25 -3497.60 -1183.60 -3276.97
# ------------------  --------------
# VF_error_after           0.0308758
# VF_error_before          0.0402383
# alpha                    0.827006
# delta                    0.1
# env_samples         248880
# eval_score           -1183.6
# eval_success             0
# kl_dist                  0.0487922
# num_samples           9490
# rollout_success          0
# running_score        -4019.32
# rwd_dense              -34.976
# rwd_sparse              -0.332641
# stoc_pol_max            86.0752
# stoc_pol_mean        -3497.6
# stoc_pol_min         -5041.11
# stoc_pol_std          1102.7
# success_percentage       0
# surr_improvement         0.132743
# time_VF                  4.08717
# time_npg                 1.60291
# time_sampling           16.4778
# time_vpg                 0.0487378
# ------------------  --------------
# ......................................................................................
# ITERATION : 26
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:52:25 2025 ]   26 -3091.44 -1729.45 -3276.97
# ------------------  --------------
# VF_error_after           0.051657
# VF_error_before          0.0730701
# alpha                    0.747538
# delta                    0.1
# env_samples         258456
# eval_score           -1729.45
# eval_success             0
# kl_dist                  0.0447125
# num_samples           9576
# rollout_success          0
# running_score        -3926.53
# rwd_dense              -30.9196
# rwd_sparse              -0.337981
# stoc_pol_max            59.7451
# stoc_pol_mean        -3091.44
# stoc_pol_min         -5031.34
# stoc_pol_std          1305.42
# success_percentage       0
# surr_improvement         0.119225
# time_VF                  4.17668
# time_npg                 1.61783
# time_sampling           16.772
# time_vpg                 0.0585103
# ------------------  --------------
# ......................................................................................
# ITERATION : 27
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:52:49 2025 ]   27 -2867.22 -1228.96 -3091.44
# ------------------  --------------
# VF_error_after           0.0578715
# VF_error_before          0.0764304
# alpha                    0.844668
# delta                    0.1
# env_samples         267847
# eval_score           -1228.96
# eval_success             0
# kl_dist                  0.0492578
# num_samples           9391
# rollout_success          0
# running_score        -3820.6
# rwd_dense              -28.6721
# rwd_sparse              -0.269372
# stoc_pol_max            36.8536
# stoc_pol_mean        -2867.22
# stoc_pol_min         -5039.32
# stoc_pol_std          1387.75
# success_percentage       0
# surr_improvement         0.147577
# time_VF                  4.09451
# time_npg                 1.58115
# time_sampling           15.9556
# time_vpg                 0.0486598
# ------------------  --------------
# ......................................................................................
# ITERATION : 28
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:53:14 2025 ]   28 -2966.21 -1174.06 -2867.22
# ------------------  --------------
# VF_error_after           0.077713
# VF_error_before          0.0984988
# alpha                    0.865893
# delta                    0.1
# env_samples         277360
# eval_score           -1174.06
# eval_success             0
# kl_dist                  0.0512118
# num_samples           9513
# rollout_success          0
# running_score        -3735.16
# rwd_dense              -29.6673
# rwd_sparse              -0.275682
# stoc_pol_max           232.365
# stoc_pol_mean        -2966.21
# stoc_pol_min         -5070.87
# stoc_pol_std          1522.55
# success_percentage       0
# surr_improvement         0.133216
# time_VF                  4.12857
# time_npg                 1.61333
# time_sampling           16.2833
# time_vpg                 0.0501709
# ------------------  --------------
# ......................................................................................
# ITERATION : 29
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:53:38 2025 ]   29 -2821.82 -388.64 -2867.22
# ------------------  --------------
# VF_error_after           0.0509101
# VF_error_before          0.0714268
# alpha                    0.794981
# delta                    0.1
# env_samples         286665
# eval_score            -388.64
# eval_success             0
# kl_dist                  0.0496993
# num_samples           9305
# rollout_success          0
# running_score        -3643.82
# rwd_dense              -28.2182
# rwd_sparse              -0.274599
# stoc_pol_max           163.394
# stoc_pol_mean        -2821.82
# stoc_pol_min         -5035.55
# stoc_pol_std          1711.97
# success_percentage       0
# surr_improvement         0.136876
# time_VF                  4.0335
# time_npg                 1.57726
# time_sampling           15.9165
# time_vpg                 0.0487607
# ------------------  --------------
# ......................................................................................
# ITERATION : 30
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:54:02 2025 ]   30 -2561.05 -1339.51 -2821.82
# ------------------  --------------
# VF_error_after           0.0646714
# VF_error_before          0.0831021
# alpha                    0.825234
# delta                    0.1
# env_samples         296007
# eval_score           -1339.51
# eval_success             0
# kl_dist                  0.0490795
# num_samples           9342
# rollout_success          0
# running_score        -3535.55
# rwd_dense              -25.6157
# rwd_sparse              -0.247378
# stoc_pol_max           110.429
# stoc_pol_mean        -2561.05
# stoc_pol_min         -5032.53
# stoc_pol_std          1646.69
# success_percentage       0
# surr_improvement         0.123741
# time_VF                  4.08506
# time_npg                 1.5787
# time_sampling           15.9529
# time_vpg                 0.0491207
# ------------------  --------------
# ......................................................................................
# ITERATION : 31
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:54:27 2025 ]   31 -2764.31 -628.65 -2561.05
# ------------------  --------------
# VF_error_after           0.065785
# VF_error_before          0.0872117
# alpha                    0.81614
# delta                    0.1
# env_samples         305396
# eval_score            -628.645
# eval_success             0
# kl_dist                  0.0464721
# num_samples           9389
# rollout_success          0
# running_score        -3458.42
# rwd_dense              -27.6431
# rwd_sparse              -0.24137
# stoc_pol_max            61.8074
# stoc_pol_mean        -2764.31
# stoc_pol_min         -5038.53
# stoc_pol_std          1509.43
# success_percentage       0
# surr_improvement         0.125672
# time_VF                  4.01655
# time_npg                 1.60975
# time_sampling           16.2957
# time_vpg                 0.0490062
# ------------------  --------------
# ......................................................................................
# ITERATION : 32
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:54:51 2025 ]   32 -2583.66 -528.73 -2561.05
# ------------------  --------------
# VF_error_after           0.0540419
# VF_error_before          0.0733973
# alpha                    0.829914
# delta                    0.1
# env_samples         314863
# eval_score            -528.733
# eval_success             0
# kl_dist                  0.0508654
# num_samples           9467
# rollout_success          0
# running_score        -3370.95
# rwd_dense              -25.8366
# rwd_sparse              -0.2617
# stoc_pol_max           159.965
# stoc_pol_mean        -2583.66
# stoc_pol_min         -5045.59
# stoc_pol_std          1654.55
# success_percentage       0
# surr_improvement         0.154278
# time_VF                  4.10424
# time_npg                 1.61489
# time_sampling           16.1987
# time_vpg                 0.0488174
# ------------------  --------------
# ......................................................................................
# ITERATION : 33
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:55:16 2025 ]   33 -2831.53 -588.73 -2561.05
# ------------------  --------------
# VF_error_after           0.0806453
# VF_error_before          0.119063
# alpha                    0.795778
# delta                    0.1
# env_samples         324314
# eval_score            -588.734
# eval_success             0
# kl_dist                  0.048502
# num_samples           9451
# rollout_success          0
# running_score        -3317.01
# rwd_dense              -28.3153
# rwd_sparse              -0.26413
# stoc_pol_max           151.254
# stoc_pol_mean        -2831.53
# stoc_pol_min         -5030.43
# stoc_pol_std          1497.42
# success_percentage       0
# surr_improvement         0.108326
# time_VF                  4.06699
# time_npg                 1.58857
# time_sampling           16.1504
# time_vpg                 0.0509233
# ------------------  --------------
# ......................................................................................
# ITERATION : 34
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:55:40 2025 ]   34 -2271.56 -1249.30 -2561.05
# ------------------  --------------
# VF_error_after           0.0988677
# VF_error_before          0.125935
# alpha                    0.870885
# delta                    0.1
# env_samples         333758
# eval_score           -1249.3
# eval_success             0
# kl_dist                  0.0531922
# num_samples           9444
# rollout_success          0
# running_score        -3212.46
# rwd_dense              -22.7156
# rwd_sparse              -0.233964
# stoc_pol_max            99.5232
# stoc_pol_mean        -2271.56
# stoc_pol_min         -5036.35
# stoc_pol_std          1511.43
# success_percentage       0
# surr_improvement         0.12131
# time_VF                  4.07363
# time_npg                 1.60812
# time_sampling           16.3112
# time_vpg                 0.0462613
# ------------------  --------------
# ......................................................................................
# ITERATION : 35
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:56:05 2025 ]   35 -2512.97 -713.67 -2271.56
# ------------------  --------------
# VF_error_after           0.0855412
# VF_error_before          0.110385
# alpha                    0.871841
# delta                    0.1
# env_samples         343144
# eval_score            -713.671
# eval_success             0
# kl_dist                  0.0482324
# num_samples           9386
# rollout_success          0
# running_score        -3142.51
# rwd_dense              -25.1297
# rwd_sparse              -0.222856
# stoc_pol_max           151.5
# stoc_pol_mean        -2512.97
# stoc_pol_min         -5031.63
# stoc_pol_std          1552.49
# success_percentage       0
# surr_improvement         0.117021
# time_VF                  4.0426
# time_npg                 1.59074
# time_sampling           16.0044
# time_vpg                 0.0479596
# ------------------  --------------
# ......................................................................................
# ITERATION : 36
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:56:29 2025 ]   36 -2315.75 -1229.28 -2271.56
# ------------------  --------------
# VF_error_after           0.0819739
# VF_error_before          0.106324
# alpha                    0.844724
# delta                    0.1
# env_samples         352551
# eval_score           -1229.28
# eval_success             0
# kl_dist                  0.0492017
# num_samples           9407
# rollout_success          0
# running_score        -3059.84
# rwd_dense              -23.1575
# rwd_sparse              -0.242161
# stoc_pol_max            65.583
# stoc_pol_mean        -2315.75
# stoc_pol_min         -5030.03
# stoc_pol_std          1494.98
# success_percentage       0
# surr_improvement         0.11977
# time_VF                  4.0172
# time_npg                 1.59727
# time_sampling           16.0161
# time_vpg                 0.0490377
# ------------------  --------------
# ......................................................................................
# ITERATION : 37
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:56:53 2025 ]   37 -2385.68 -738.91 -2271.56
# ------------------  --------------
# VF_error_after           0.116259
# VF_error_before          0.17169
# alpha                    0.731955
# delta                    0.1
# env_samples         361870
# eval_score            -738.908
# eval_success             0
# kl_dist                  0.0496008
# num_samples           9319
# rollout_success          0
# running_score        -2992.42
# rwd_dense              -23.8568
# rwd_sparse              -0.256154
# stoc_pol_max           122.816
# stoc_pol_mean        -2385.68
# stoc_pol_min         -4875.45
# stoc_pol_std          1568.69
# success_percentage       0
# surr_improvement         0.21937
# time_VF                  4.04349
# time_npg                 1.56688
# time_sampling           16.1096
# time_vpg                 0.0479662
# ------------------  --------------
# ......................................................................................
# ITERATION : 38
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:57:18 2025 ]   38 -2638.02 -728.53 -2271.56
# ------------------  --------------
# VF_error_after           0.0711795
# VF_error_before          0.0957703
# alpha                    0.805997
# delta                    0.1
# env_samples         371398
# eval_score            -728.531
# eval_success             0
# kl_dist                  0.0544437
# num_samples           9528
# rollout_success          0
# running_score        -2956.98
# rwd_dense              -26.3863
# rwd_sparse              -0.293368
# stoc_pol_max           104.574
# stoc_pol_mean        -2638.02
# stoc_pol_min         -5034.67
# stoc_pol_std          1634.26
# success_percentage       0
# surr_improvement         0.108701
# time_VF                  4.07999
# time_npg                 1.6182
# time_sampling           16.5451
# time_vpg                 0.0570397
# ------------------  --------------
# ......................................................................................
# ITERATION : 39
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:57:43 2025 ]   39 -2294.26 -643.62 -2271.56
# ------------------  --------------
# VF_error_after           0.0842064
# VF_error_before          0.114594
# alpha                    0.842859
# delta                    0.1
# env_samples         380818
# eval_score            -643.619
# eval_success             0
# kl_dist                  0.0492603
# num_samples           9420
# rollout_success          0
# running_score        -2890.71
# rwd_dense              -22.9483
# rwd_sparse              -0.224602
# stoc_pol_max           144.567
# stoc_pol_mean        -2294.26
# stoc_pol_min         -5037.04
# stoc_pol_std          1561.39
# success_percentage       0
# surr_improvement         0.133182
# time_VF                  4.02084
# time_npg                 1.57953
# time_sampling           16.2469
# time_vpg                 0.0484793
# ------------------  --------------
# ......................................................................................
# ITERATION : 40
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:58:08 2025 ]   40 -2514.87 -768.73 -2271.56
# ------------------  --------------
# VF_error_after           0.104214
# VF_error_before          0.145103
# alpha                    0.852954
# delta                    0.1
# env_samples         390392
# eval_score            -768.733
# eval_success             0
# kl_dist                  0.0506313
# num_samples           9574
# rollout_success          0
# running_score        -2853.12
# rwd_dense              -25.1487
# rwd_sparse              -0.277706
# stoc_pol_max           192.812
# stoc_pol_mean        -2514.87
# stoc_pol_min         -5028.33
# stoc_pol_std          1698.59
# success_percentage       0
# surr_improvement         0.10439
# time_VF                  4.11684
# time_npg                 1.63017
# time_sampling           16.5512
# time_vpg                 0.0514104
# ------------------  --------------
# ......................................................................................
# ITERATION : 41
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:58:32 2025 ]   41 -1908.85 -1048.89 -2271.56
# ------------------  -------------
# VF_error_after           0.083848
# VF_error_before          0.140714
# alpha                    0.681675
# delta                    0.1
# env_samples         399857
# eval_score           -1048.89
# eval_success             0
# kl_dist                  0.050856
# num_samples           9465
# rollout_success          0
# running_score        -2758.7
# rwd_dense              -19.0938
# rwd_sparse              -0.211277
# stoc_pol_max           135.032
# stoc_pol_mean        -1908.85
# stoc_pol_min         -5023.77
# stoc_pol_std          1597.12
# success_percentage       0
# surr_improvement         0.161035
# time_VF                  3.99477
# time_npg                 1.59961
# time_sampling           16.3339
# time_vpg                 0.04848
# ------------------  -------------
# ......................................................................................
# ITERATION : 42
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:58:57 2025 ]   42 -2029.13 -1288.97 -1908.85
# ------------------  --------------
# VF_error_after           0.0875731
# VF_error_before          0.123506
# alpha                    0.782519
# delta                    0.1
# env_samples         409404
# eval_score           -1288.97
# eval_success             0
# kl_dist                  0.0509873
# num_samples           9547
# rollout_success          0
# running_score        -2685.74
# rwd_dense              -20.2913
# rwd_sparse              -0.198157
# stoc_pol_max           114.423
# stoc_pol_mean        -2029.13
# stoc_pol_min         -4880.28
# stoc_pol_std          1545.29
# success_percentage       0
# surr_improvement         0.122909
# time_VF                  4.10342
# time_npg                 1.61789
# time_sampling           16.4654
# time_vpg                 0.0492458
# ------------------  --------------
# ......................................................................................
# ITERATION : 43
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0AA89E0>
# [ Wed May 14 06:59:22 2025 ]   43 -1835.00 -1203.90 -1908.85
# ------------------  --------------
# VF_error_after           0.106709
# VF_error_before          0.183915
# alpha                    0.786326
# delta                    0.1
# env_samples         418854
# eval_score           -1203.9
# eval_success             0
# kl_dist                  0.0483046
# num_samples           9450
# rollout_success          0
# running_score        -2600.67
# rwd_dense              -18.3553
# rwd_sparse              -0.211952
# stoc_pol_max           155.264
# stoc_pol_mean        -1835
# stoc_pol_min         -4972.25
# stoc_pol_std          1528.17
# success_percentage       0
# surr_improvement         0.165189
# time_VF                  4.07229
# time_npg                 1.61363
# time_sampling           16.2468
# time_vpg                 0.0461736
# ------------------  --------------
# ......................................................................................
# ITERATION : 44
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD0A67430>
# [ Wed May 14 06:59:46 2025 ]   44 -1927.55 -1369.04 -1835.00
# ------------------  --------------
# VF_error_after           0.117612
# VF_error_before          0.163829
# alpha                    0.849408
# delta                    0.1
# env_samples         428162
# ...
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1835
# Performing evaluation rollouts ........
# Simulation couldn't be stepped as intended. Issuing a reset
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:16:29 2025 ] 1835 -238.94 -836.12 -36.02
# ------------------  ---------------
# VF_error_after          0.404831
# VF_error_before         0.908041
# alpha                   0.137862
# delta                   0.1
# env_samples             1.75902e+07
# eval_score           -836.116
# eval_success            0
# kl_dist                 0.0486047
# num_samples          9600
# rollout_success         0
# running_score        -327.293
# rwd_dense              -2.39465
# rwd_sparse             -0.161105
# stoc_pol_max          136.588
# stoc_pol_mean        -238.941
# stoc_pol_min        -3736.95
# stoc_pol_std          621.888
# success_percentage      0
# surr_improvement      inf
# time_VF                 4.25655
# time_npg                1.58499
# time_sampling          16.2768
# time_vpg                0.0491865
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1836
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:16:54 2025 ] 1836 -414.45 -524.05 -36.02
# ------------------  ---------------
# VF_error_after          0.206515
# VF_error_before         0.492991
# alpha                   0.0903725
# delta                   0.1
# env_samples             1.75998e+07
# eval_score           -524.049
# eval_success            0
# kl_dist                 0.049378
# num_samples          9600
# rollout_success         0
# running_score        -336.009
# rwd_dense              -4.14456
# rwd_sparse             -0.180396
# stoc_pol_max          173.676
# stoc_pol_mean        -414.454
# stoc_pol_min        -4383.19
# stoc_pol_std          818.218
# success_percentage      0
# surr_improvement       -1.54394e+18
# time_VF                 4.24834
# time_npg                1.57564
# time_sampling          16.2009
# time_vpg                0.0479884
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1837
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:17:19 2025 ] 1837 -421.26 -547.56 -36.02
# ------------------  ---------------
# VF_error_after          0.182112
# VF_error_before         0.531779
# alpha                   0.110592
# delta                   0.1
# env_samples             1.76094e+07
# eval_score           -547.564
# eval_success            0
# kl_dist                 0.0473636
# num_samples          9600
# rollout_success         0
# running_score        -344.534
# rwd_dense              -4.21783
# rwd_sparse             -0.169075
# stoc_pol_max          169.137
# stoc_pol_mean        -421.259
# stoc_pol_min        -4071
# stoc_pol_std          894.546
# success_percentage      0
# surr_improvement        6.67266e+28
# time_VF                 4.25343
# time_npg                1.58685
# time_sampling          16.1834
# time_vpg                0.0476451
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1838
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:17:44 2025 ] 1838 -307.30 -516.08 -36.02
# ------------------  --------------
# VF_error_after          0.20097
# VF_error_before         0.464458
# alpha                   0.108378
# delta                   0.1
# env_samples             1.7619e+07
# eval_score           -516.08
# eval_success            0
# kl_dist                 0.0499551
# num_samples          9600
# rollout_success         0
# running_score        -340.811
# rwd_dense              -3.07826
# rwd_sparse             -0.168049
# stoc_pol_max          285.959
# stoc_pol_mean        -307.302
# stoc_pol_min        -4748.89
# stoc_pol_std          776.095
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.24059
# time_npg                1.57651
# time_sampling          16.1924
# time_vpg                0.0471671
# ------------------  --------------
# ......................................................................................
# ITERATION : 1839
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:18:08 2025 ] 1839 -220.79 -567.92 -36.02
# ------------------  ---------------
# VF_error_after          0.129564
# VF_error_before         0.576988
# alpha                   0.0733386
# delta                   0.1
# env_samples             1.76286e+07
# eval_score           -567.923
# eval_success            0
# kl_dist                 0.0526737
# num_samples          9600
# rollout_success         0
# running_score        -328.808
# rwd_dense              -2.21312
# rwd_sparse             -0.158536
# stoc_pol_max          351.089
# stoc_pol_mean        -220.789
# stoc_pol_min        -4721.66
# stoc_pol_std          635.111
# success_percentage      0
# surr_improvement        2.83006e+20
# time_VF                 4.21379
# time_npg                1.58526
# time_sampling          16.1725
# time_vpg                0.0470479
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1840
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:18:33 2025 ] 1840 -388.42 -557.12 -36.02
# ------------------  ---------------
# VF_error_after          0.262562
# VF_error_before         0.565663
# alpha                   0.10693
# delta                   0.1
# env_samples             1.76382e+07
# eval_score           -557.12
# eval_success            0
# kl_dist                 0.0490055
# num_samples          9600
# rollout_success         0
# running_score        -334.77
# rwd_dense              -3.88945
# rwd_sparse             -0.16445
# stoc_pol_max          269.776
# stoc_pol_mean        -388.422
# stoc_pol_min        -4071.48
# stoc_pol_std          875.679
# success_percentage      0
# surr_improvement      inf
# time_VF                 4.28762
# time_npg                1.58254
# time_sampling          16.1269
# time_vpg                0.0472403
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1841
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:18:58 2025 ] 1841 -305.49 -607.78 -36.02
# ------------------  ---------------
# VF_error_after          0.191124
# VF_error_before         0.467452
# alpha                   0.0987489
# delta                   0.1
# env_samples             1.76478e+07
# eval_score           -607.776
# eval_success            0
# kl_dist                 0.0498644
# num_samples          9600
# rollout_success         0
# running_score        -331.842
# rwd_dense              -3.06015
# rwd_sparse             -0.174112
# stoc_pol_max          164.827
# stoc_pol_mean        -305.492
# stoc_pol_min        -4704.96
# stoc_pol_std          684.27
# success_percentage      0
# surr_improvement      inf
# time_VF                 4.29233
# time_npg                1.58573
# time_sampling          16.1263
# time_vpg                0.0554287
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1842
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:19:23 2025 ] 1842 -378.32 -541.55 -36.02
# ------------------  ---------------
# VF_error_after          0.157156
# VF_error_before         0.433435
# alpha                   0.0850744
# delta                   0.1
# env_samples             1.76574e+07
# eval_score           -541.548
# eval_success            0
# kl_dist                 0.0463629
# num_samples          9600
# rollout_success         0
# running_score        -336.489
# rwd_dense              -3.78839
# rwd_sparse             -0.176513
# stoc_pol_max          172.953
# stoc_pol_mean        -378.315
# stoc_pol_min        -4809.25
# stoc_pol_std          832.522
# success_percentage      0
# surr_improvement      inf
# time_VF                 4.28776
# time_npg                1.60575
# time_sampling          16.1385
# time_vpg                0.0473943
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1843
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:19:48 2025 ] 1843 -241.67 -534.36 -36.02
# ------------------  --------------
# VF_error_after          0.175064
# VF_error_before         0.599483
# alpha                   0.0649329
# delta                   0.1
# env_samples             1.7667e+07
# eval_score           -534.357
# eval_success            0
# kl_dist                 0.0459361
# num_samples          9600
# rollout_success         0
# running_score        -327.007
# rwd_dense              -2.42194
# rwd_sparse             -0.158394
# stoc_pol_max          330.72
# stoc_pol_mean        -241.671
# stoc_pol_min        -3781.29
# stoc_pol_std          599.48
# success_percentage      0
# surr_improvement    41450.1
# time_VF                 4.21555
# time_npg                1.57254
# time_sampling          16.0778
# time_vpg                0.0480926
# ------------------  --------------
# ......................................................................................
# ITERATION : 1844
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:20:12 2025 ] 1844 -303.19 -534.15 -36.02
# ------------------  ---------------
# VF_error_after          0.148577
# VF_error_before         0.477729
# alpha                   0.0736453
# delta                   0.1
# env_samples             1.76766e+07
# eval_score           -534.154
# eval_success            0
# kl_dist                 0.0461714
# num_samples          9600
# rollout_success         0
# running_score        -324.626
# rwd_dense              -3.03717
# rwd_sparse             -0.163632
# stoc_pol_max          249.628
# stoc_pol_mean        -303.194
# stoc_pol_min        -4137.39
# stoc_pol_std          603.658
# success_percentage      0
# surr_improvement      inf
# time_VF                 4.24029
# time_npg                1.59096
# time_sampling          16.252
# time_vpg                0.0472221
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1845
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:20:37 2025 ] 1845 -315.13 -526.28 -36.02
# ------------------  ---------------
# VF_error_after          0.280735
# VF_error_before         0.729536
# alpha                   0.0614465
# delta                   0.1
# env_samples             1.76862e+07
# eval_score           -526.282
# eval_success            0
# kl_dist                 0.0503147
# num_samples          9600
# rollout_success         0
# running_score        -323.676
# rwd_dense              -3.15648
# rwd_sparse             -0.170441
# stoc_pol_max          266.072
# stoc_pol_mean        -315.125
# stoc_pol_min        -4278.55
# stoc_pol_std          717.728
# success_percentage      0
# surr_improvement        7.37694e+18
# time_VF                 4.23612
# time_npg                1.57765
# time_sampling          16.1531
# time_vpg                0.0474792
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1846
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:21:02 2025 ] 1846 -352.69 -537.15 -36.02
# ------------------  ---------------
# VF_error_after          0.20768
# VF_error_before         0.411043
# alpha                   0.110165
# delta                   0.1
# env_samples             1.76958e+07
# eval_score           -537.153
# eval_success            0
# kl_dist                 0.0517921
# num_samples          9600
# rollout_success         0
# running_score        -326.578
# rwd_dense              -3.53216
# rwd_sparse             -0.175909
# stoc_pol_max          379.347
# stoc_pol_mean        -352.693
# stoc_pol_min        -3828.49
# stoc_pol_std          746.888
# success_percentage      0
# surr_improvement      inf
# time_VF                 4.25325
# time_npg                1.5787
# time_sampling          16.1246
# time_vpg                0.047662
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1847
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:21:27 2025 ] 1847 -182.60 -540.37 -36.02
# ------------------  ---------------
# VF_error_after          0.320849
# VF_error_before         1.38132
# alpha                   0.0619182
# delta                   0.1
# env_samples             1.77054e+07
# eval_score           -540.371
# eval_success            0
# kl_dist                 0.0473585
# num_samples          9600
# rollout_success         0
# running_score        -312.18
# rwd_dense              -1.83122
# rwd_sparse             -0.164348
# stoc_pol_max           96.6796
# stoc_pol_mean        -182.599
# stoc_pol_min        -2769.68
# stoc_pol_std          366.483
# success_percentage      0
# surr_improvement      inf
# time_VF                 4.22689
# time_npg                1.58023
# time_sampling          16.0944
# time_vpg                0.0481763
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1848
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:21:51 2025 ] 1848 -399.06 -609.92 -36.02
# ------------------  ---------------
# VF_error_after          0.145943
# VF_error_before         0.580366
# alpha                   0.0794831
# delta                   0.1
# env_samples             1.7715e+07
# eval_score           -609.923
# eval_success            0
# kl_dist                 0.0495286
# num_samples          9600
# rollout_success         0
# running_score        -320.868
# rwd_dense              -3.99583
# rwd_sparse             -0.186868
# stoc_pol_max           80.1933
# stoc_pol_mean        -399.059
# stoc_pol_min        -4727.55
# stoc_pol_std          970.655
# success_percentage      0
# surr_improvement        5.47485e+11
# time_VF                 4.25526
# time_npg                1.59217
# time_sampling          16.1011
# time_vpg                0.0476391
# ------------------  ---------------
# ......................................................................................
# ITERATION : 1849
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001CBD347CF20>
# [ Wed May 14 20:22:16 2025 ] 1849 -427.29 -550.39 -36.02
# ------------------  ---------------
# VF_error_after          0.147155
# VF_error_before         0.398674
# alpha                   0.0754783
# delta                   0.1
# env_samples             1.77246e+07
# eval_score           -550.392
# eval_success            0
# kl_dist                 0.0487363
# num_samples          9600
# rollout_success         0
# running_score        -331.51
# rwd_dense              -4.27817
# rwd_sparse             -0.192131
# stoc_pol_max          245.838
# stoc_pol_mean        -427.293
# stoc_pol_min        -4631.61
# stoc_pol_std          908.719
# success_percentage      0
# surr_improvement      inf
# time_VF                 4.24453
# time_npg                1.58654
# time_sampling          16.0981
# time_vpg                0.048125
# ------------------  ---------------
# ========================================
# Job Finished.
# ========================================

# %% [markdown]
# <h1> Logging hyperparameters

# %%
import logging

# Configure the logging system
logging.basicConfig(
    filename=r'C:\Users\Elyas\OneDrive - The University of Colorado Denver\Desktop\Research 2024\Research_papers/training_hyperparameters.log',  # Log file name
    level=logging.INFO,  # Set the logging level to INFO
    format='%(asctime)s - %(levelname)s - %(message)s',  # Log message format
)

# %%
# Policy Network Hyperparameters
policy_hyperparameters = {
    'policy_size': (256, 256),
    'seed': 123,
    'rl_step_size': 0.1,
    'learnrate': 0.0025,
    'entcoeff': 0.1,
    'batchsize': 32,
    'num_epoch': 10,
}

# Value Function Network Hyperparameters
vf_hyperparameters = {
    'vf_hidden_size': (256, 256),
    'seed': 123,
    'rl_step_size': 0.1,
    'learnrate': 0.000325,
    'entcoeff': 0.1,
    'batchsize': 32,
    'num_epoch': 10,
    'regcoef': 1e-3,
}

# Training Hyperparameters
training_hyperparameters = {
    'iterations': 1000,
    'gamma': 0.995,
    'gae_lambda': 0.97,
}

# Log Hyperparameters
def log_hyperparameters():
    logging.info("Policy Network Hyperparameters:")
    for key, value in policy_hyperparameters.items():
        logging.info(f"{key}: {value}")
    
    logging.info("\nValue Function Network Hyperparameters:")
    for key, value in vf_hyperparameters.items():
        logging.info(f"{key}: {value}")
    
    logging.info("\nTraining Hyperparameters:")
    for key, value in training_hyperparameters.items():
        logging.info(f"{key}: {value}")

# Call the function to log hyperparameters
log_hyperparameters()
